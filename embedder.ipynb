# %%
import torch

# Set device to 'mps' if available, otherwise use 'cpu'
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: mps

# %%
tr_cosmos_embeddings = torch.load('tr_cosmos_embeddings.pt')
print(tr_cosmos_embeddings.shape)
# Out:
# torch.Size([30158, 768])
# /var/folders/gs/crm1zcvj00j1kl0l1lvz4qf40000gn/T/ipykernel_41200/924132526.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   tr_cosmos_embeddings = torch.load('tr_cosmos_embeddings.pt')

# %%
# save embbedings split to 6 parts so that we can push to github
for i in range(3):
    torch.save(tr_cosmos_embeddings[i * 10100:(i + 1) * 10100], f'tr_cosmos_embeddings_{i}.pt')

# %%
tr_embeddings = []

for i in range(3):
    tr_embeddings.append(torch.load(f'tr_cosmos_embeddings_{i}.pt'))

tr_embeddings = torch.cat(tr_embeddings)

print(tr_embeddings.shape)
# Out:
# torch.Size([30158, 768])
# /var/folders/gs/crm1zcvj00j1kl0l1lvz4qf40000gn/T/ipykernel_41200/1402031403.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   tr_embeddings.append(torch.load(f'tr_cosmos_embeddings_{i}.pt'))

# %%
from datasets import load_dataset
from codes.pre_processor import PreProcessor

ds = load_dataset("alibayram/doktorsitesi")
df = ds['train'].to_pandas()

preprocessor = PreProcessor(df)
df = preprocessor.preprocess()
df
# Out:
# /Users/alibayram/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
#         doctor_title doctor_speciality  \
# 0       dr-ogr-uyesi           cerrahi
# 1       uzman-doktor       dermatoloji
# 2       uzman-doktor           cerrahi
# 3       uzman-doktor           cerrahi
# 4       uzman-doktor       kadın-dogum
# ...              ...               ...
# 187627  uzman-doktor       kadın-dogum
# 187628  uzman-doktor           cerrahi
# 187629  uzman-doktor       kadın-dogum
# 187630        docent           cerrahi
# 187631      profesor     diş-hekimliği
#
#                                          question_content  \
# 0       Merhaba, Yaklaşık 4 aydır sağ omuzumda kolumu ...
# 1       Vücudumun farklı bölgelerinde küçük sivrisinek...
# 2       Hocam merhaba 29 yaşında erkek hasta hareketle...
# 3       Meraba hocam sorum şu , bir erkek bayıltılıp a...
# 4       Merhaba doktor hanim ben 3 yildir evliyim. Hic...
# ...                                                   ...
# 187627  hocam merhaba , son kontrolüme göre gebelik ha...
# 187628  Hocam 15 yildir basur sikintisi çeken biriyim ...
# 187629  hocam öncelikle meraba ortalama 3 yıl önce kad...
# 187630  Merhaba hocam testis kanseri olan hastalarda k...
# 187631  İyi günler. ben bleaching dişbeyazlatma sistem...
#
#                                           question_answer
# 0       Merhabalar geçmiş olsun mr raporuna göre omzum...
# 1       Merhaba, Eğer yaralar kaşıntıyla beraber oluyo...
# 2       Şikayetinizin daha iyi anlaşılabilmesi için mu...
# 3       Bir kimseye tecavüz edilmişse anal mukozada ir...
# 4       Merhaba tiroıd bezinin düzenli çalışmaması geb...
# ...                                                   ...
# 187627  tek nir bpd ölçülerek bebek hakkında olumsuzlu...
# 187628  tuvalete gitmediğiniz sürece kanama olmaması b...
# 187629  Mrhaba bu grup ilaçlar adeti kesebiliyor,tekra...
# 187630                 Çok seyrek görülen bir belirtidir.
# 187631  Nuran hanım diş beyazlatma hekim kontrolunde y...
#
# [187632 rows x 4 columns]

# %%
doctor_speciality_list = df['doctor_speciality'].unique().tolist()
doctor_speciality_list
# Out:
# ['ortopedi-ve-travmatoloji',
#  'dermatoloji',
#  'ortopedi-ve-travmatoloji-el-cerrahisi-ve-mikrocerrahi',
#  'genel-cerrahi-proktoloji',
#  'kadin-hastaliklari-ve-dogum-jinekolojik-onkoloji',
#  'diyetisyen',
#  'kadin-hastaliklari-ve-dogum-ureme-endokrinolojisi-ve-infertilite',
#  'fiziksel-tip-ve-rehabilitasyon',
#  'beyin-ve-sinir-cerrahisi',
#  'uroloji',
#  'kadin-hastaliklari-ve-dogum',
#  'genel-cerrahi',
#  'dahiliye-ve-ic-hastaliklari-endokrinoloji-ve-metabolizma-hastaliklari',
#  'dahiliye-ve-ic-hastaliklari-gastroenteroloji',
#  'goz-hastaliklari',
#  'medikal-estetik-sertifikali-tip-doktoru',
#  'cocuk-sagligi-ve-hastaliklari-cocuk-norolojisi',
#  'cocuk-psikiyatrisi',
#  'plastik-rekonstruktif-ve-estetik-cerrahi',
#  'psikoloji',
#  'cocuk-sagligi-ve-hastaliklari-cocuk-immunolojisi-ve-alerji-hastaliklari',
#  'aile-hekimligi',
#  'fiziksel-tip-ve-rehabilitasyon-fiziksel-tip-ve-rehabilitasyon-algoloji',
#  'acil-tip',
#  'cocuk-sagligi-ve-hastaliklari-cocuk-hematoloji',
#  'dahiliye-ve-ic-hastaliklari-nefroloji',
#  'kardiyoloji',
#  'dis-hekimi',
#  'gogus-cerrahisi',
#  'cocuk-sagligi-ve-hastaliklari-cocuk-endokrinoloji',
#  'uroloji-androloji',
#  'tibbi-genetik',
#  'gogus-hastaliklari',
#  'kulak-burun-bogaz-hastaliklari',
#  'tibbi-farmakoloji',
#  'dis-hekimi-pedodonti',
#  'cocuk-sagligi-ve-hastaliklari',
#  'anestezi-ve-reanimasyon-algoloji-anestezi-ve-reanimasyon',
#  'kadin-hastaliklari-ve-dogum-perinatoloji',
#  'pratisyen-hekimlik',
#  'cocuk-sagligi-ve-hastaliklari-cocuk-gogus-hastaliklari',
#  'veteriner',
#  'enfeksiyon-hastaliklari-ve-klinik-mikrobiyoloji',
#  'kalp-damar-cerrahisi',
#  'tibbi-biyokimya',
#  'psikiyatri',
#  'genel-cerrahi-cerrahi-onkoloji',
#  'noroloji',
#  'dis-hekimi-ortodonti',
#  'geleneksel-ve-tamamlayici-tip',
#  'dahiliye-ve-ic-hastaliklari-immunoloji-ve-alerji-hastaliklari',
#  'romatoloji-dahiliye-ve-ic-hastaliklari',
#  'cocuk-sagligi-ve-hastaliklari-cocuk-kardiyolojisi',
#  'noroloji-klinik-norofizyoloji',
#  'dahiliye-ve-ic-hastaliklari-immunoloji',
#  'radyoloji',
#  'dahiliye-ve-ic-hastaliklari',
#  'akupunktur',
#  'dis-hekimi-agiz-dis-ve-cene-cerrahisi',
#  'noroloji-noroloji-algoloji',
#  'tibbi-patoloji',
#  'cocuk-sagligi-ve-hastaliklari-cocuk-enfeksiyon-hastaliklari',
#  'cocuk-cerrahisi',
#  'cocuk-cerrahisi-cocuk-cerrahisi-cocuk-urolojisi',
#  'tibbi-onkoloji-dahiliye-ve-ic-hastaliklari',
#  'fizyoterapi',
#  'cocuk-sagligi-ve-hastaliklari-neonatoloji',
#  'cocuk-cerrahisi-cocuk-cerrahisi-cocuk-urolojisi-cocuk-urolojisi-uroloji',
#  'radyasyon-onkolojisi',
#  'dis-hekimi-oral-implantoloji',
#  'algoloji',
#  'psikolojik-danisman',
#  'dis-hekimi-periodontoloji',
#  'spor-hekimligi',
#  'plastik-rekonstruktif-ve-estetik-cerrahi-el-cerrahisi-ve-mikrocerrahi-plastik',
#  'cocuk-sagligi-ve-hastaliklari-cocuk-nefrolojisi',
#  'anestezi-ve-reanimasyon',
#  'psikoloji-aile-danismani-psikolog',
#  'genel-cerrahi-endokrin-cerrahisi',
#  'dahiliye-ve-ic-hastaliklari-geriatri',
#  'dis-hekimi-dis-protezi-uzmani',
#  'anatomi',
#  'nukleer-tip',
#  'klinik-psikolog-psikoloji-aile-danismani-psikolog',
#  'pedodonti',
#  'gastroenteroloji',
#  'ergoterapi',
#  'cocuk-gelisim-uzmani',
#  'psikolojik-danisman-psikoloji',
#  'radyoloji-girisimsel-radyoloji',
#  'cocuk-sagligi-ve-hastaliklari-cocuk-genetik-hastaliklari',
#  'fiziksel-tip-ve-rehabilitasyon-fiziksel-tip-ve-rehabilitasyon-romatoloji',
#  'genel-cerrahi-meme-cerrahisi',
#  'psikoterapi',
#  'dis-hekimi-restoratif-dis-tedavisi',
#  'cocuk-sagligi-ve-hastaliklari-cocuk-romatolojisi',
#  'dil-konusma-bozuklari-b',
#  'radyoloji-uroradyoloji',
#  'endokrinoloji-ve-metabolizma-hastaliklari',
#  'kalp-damar-cerrahisi-damar-cerrahisi',
#  'dis-hekimi-oral-diagnoz-ve-radyoloji',
#  'klinik-psikolog',
#  'dil-konusma-bozuklari-b-aile-danismani',
#  'histoloji-ve-embriyoloji',
#  'tibbi-onkoloji',
#  'aile-danismani',
#  'dis-hekimi-endodonti',
#  'pedagoji',
#  'dis-hekimi-koruyucu-dis-hekimlig',
#  'genel-cerrahi-gastroenteroloji-cerrahisi',
#  'gogus-hastaliklari-alerji-ve-gogus-hastaliklari',
#  'dahiliye-ve-ic-hastaliklari-hematoloji',
#  'cocuk-sagligi-ve-hastaliklari-cocuk-gastroenterolojisi',
#  'akupunktur-biorezonans',
#  'klinik-psikolog-psikoloji',
#  'psikoloji-psikoonkoloji']

# %%
list(df['doctor_title'].unique())
# Out:
# ['Dr. Öğr. Üyesi',
#  'Uzm. Dr.',
#  'Op. Dr.',
#  'Dyt.',
#  'Yrd. Doç. Dr.',
#  'Doç. Dr.',
#  'Prof. Dr.',
#  'Dr.',
#  'Uzm. Kl. Psk.',
#  'Dt.',
#  'Dr.Öğr.Üyesi',
#  'Prof. Dr. Dt.',
#  'Veteriner Hekim',
#  'Uzm. Psk.',
#  'Psk.',
#  'Dr. Dt.',
#  'Vet.',
#  'Fzt.',
#  'Uzm. Dyt.',
#  'Uzm. Psk. Dan.',
#  'Psk. Dan.',
#  'Uzm. Dr. Dt.',
#  'Psikoterapist',
#  'Ergoterapist',
#  'Doç. Dr. Dt.',
#  'Uzm. Dt.',
#  'Çocuk Gelişim Uzmanı',
#  'Dr. Psk. Dan.',
#  'Dr. Öğr. Üyesi Dt.',
#  'Dil ve Konuşma Terapisti',
#  'Dr. Psk.',
#  'Doç. Dr. Psk. Dan',
#  'Aile Danışmanı',
#  'Pedagog',
#  'Klinik Psikolog ',
#  'Dr. Dyt. ']

# %%
reliability_scores = {
    "profesor": 10,
    "docent": 8,
    "dr-ogr-uyesi": 7,
    "uzman-doktor": 6,
    "doktor": 5,
    "diyetisyen": 4,
    "Dr. Dyt. ": 6,
    "dis-hekimi": 7,
    "veteriner": 5,
    "uzman-psikolog": 5,
    "psikolog": 4,
    "fizyoterapist": 5,
    "ergoterapist": 4,
    "cocuk-gelisim-uzmani": 3,
    "dil-ve-konusma-terapisti": 3,
    "pedagog": 3
}

# %%
# change the title to reliability score
# change the speciality to the index of the speciality
df['doctor_title'] = df['doctor_title'].apply(lambda x: reliability_scores[x])
df
# Out:
#         doctor_title doctor_speciality  \
# 0                  7           cerrahi
# 1                  6       dermatoloji
# 2                  6           cerrahi
# 3                  6           cerrahi
# 4                  6       kadın-dogum
# ...              ...               ...
# 187627             6       kadın-dogum
# 187628             6           cerrahi
# 187629             6       kadın-dogum
# 187630             8           cerrahi
# 187631            10     diş-hekimliği
#
#                                          question_content  \
# 0       Merhaba, Yaklaşık 4 aydır sağ omuzumda kolumu ...
# 1       Vücudumun farklı bölgelerinde küçük sivrisinek...
# 2       Hocam merhaba 29 yaşında erkek hasta hareketle...
# 3       Meraba hocam sorum şu , bir erkek bayıltılıp a...
# 4       Merhaba doktor hanim ben 3 yildir evliyim. Hic...
# ...                                                   ...
# 187627  hocam merhaba , son kontrolüme göre gebelik ha...
# 187628  Hocam 15 yildir basur sikintisi çeken biriyim ...
# 187629  hocam öncelikle meraba ortalama 3 yıl önce kad...
# 187630  Merhaba hocam testis kanseri olan hastalarda k...
# 187631  İyi günler. ben bleaching dişbeyazlatma sistem...
#
#                                           question_answer
# 0       Merhabalar geçmiş olsun mr raporuna göre omzum...
# 1       Merhaba, Eğer yaralar kaşıntıyla beraber oluyo...
# 2       Şikayetinizin daha iyi anlaşılabilmesi için mu...
# 3       Bir kimseye tecavüz edilmişse anal mukozada ir...
# 4       Merhaba tiroıd bezinin düzenli çalışmaması geb...
# ...                                                   ...
# 187627  tek nir bpd ölçülerek bebek hakkında olumsuzlu...
# 187628  tuvalete gitmediğiniz sürece kanama olmaması b...
# 187629  Mrhaba bu grup ilaçlar adeti kesebiliyor,tekra...
# 187630                 Çok seyrek görülen bir belirtidir.
# 187631  Nuran hanım diş beyazlatma hekim kontrolunde y...
#
# [187632 rows x 4 columns]

# %%
from transformers import AutoTokenizer

tr_tokenizer = AutoTokenizer.from_pretrained("alibayram/tr_tokenizer")
tr_tokenizer.is_fast
# Out:
# True

# %%
def embed_text(text):
    # the average of the embeddings of the tokens
    input_ids = tr_tokenizer(text)['input_ids']
    embeddings = []
    for i in input_ids:
        embeddings.append(tr_embeddings[i])
        
    list_of_embeddings = torch.stack(embeddings)
    return torch.mean(list_of_embeddings, axis=0)

embedded_text = embed_text("Merhaba, benim adım Ali. Bugün hava çok güzel.")
embedded_text.shape
# Out:
# torch.Size([768])

# %%
doctor_speciality_list_map = {i: doctor_speciality_list[i] for i in range(len(doctor_speciality_list))}
doctor_speciality_list_map
# Out:
# {0: 'cerrahi',
#  1: 'dermatoloji',
#  2: 'kadın-dogum',
#  3: 'diyetisyen',
#  4: 'fizik-tedavi-ve-rehabilitasyon',
#  5: 'dahiliye',
#  6: 'göz',
#  7: 'psikiyatri-ve-psikoloji',
#  8: 'anestezi-ve-algoloji',
#  9: 'acil-tip',
#  10: 'kardiyoloji',
#  11: 'diş-hekimliği',
#  12: 'genetik',
#  13: 'göğüs-hastaliklari',
#  14: 'kulak-burun-bogaz',
#  15: 'farmakoloji',
#  16: 'veterinerlik',
#  17: 'enfeksiyon-ve-immunoloji',
#  18: 'biyokimya',
#  19: 'noroloji',
#  20: 'geleneksel-tamamlayici-tip',
#  21: 'radyoloji-ve-onkoloji',
#  22: 'patoloji',
#  23: 'spor-hekimliği',
#  24: 'anatomi-ve-histoloji',
#  25: 'çocuk-gelişimi',
#  26: 'konuşma-terapisi'}

# %%
classes = df['doctor_speciality'].unique().tolist()
classes
# Out:
# ['cerrahi',
#  'dermatoloji',
#  'kadın-dogum',
#  'diyetisyen',
#  'fizik-tedavi-ve-rehabilitasyon',
#  'dahiliye',
#  'göz',
#  'psikiyatri-ve-psikoloji',
#  'anestezi-ve-algoloji',
#  'acil-tip',
#  'kardiyoloji',
#  'diş-hekimliği',
#  'genetik',
#  'göğüs-hastaliklari',
#  'kulak-burun-bogaz',
#  'farmakoloji',
#  'veterinerlik',
#  'enfeksiyon-ve-immunoloji',
#  'biyokimya',
#  'noroloji',
#  'geleneksel-tamamlayici-tip',
#  'radyoloji-ve-onkoloji',
#  'patoloji',
#  'spor-hekimliği',
#  'anatomi-ve-histoloji',
#  'çocuk-gelişimi',
#  'konuşma-terapisi']

# %%
number_of_examples_per_title = df['doctor_title'].value_counts().to_dict()
number_of_examples_per_title
# Out:
# {'uzman-doktor': 84907,
#  'profesor': 66231,
#  'docent': 18682,
#  'dr-ogr-uyesi': 8637,
#  'dis-hekimi': 2950,
#  'uzman-psikolog': 1863,
#  'doktor': 1323,
#  'psikolog': 1244,
#  'diyetisyen': 710,
#  'veteriner': 488,
#  'fizyoterapist': 447,
#  'cocuk-gelisim-uzmani': 75,
#  'dil-ve-konusma-terapisti': 70,
#  'ergoterapist': 2,
#  'pedagog': 2,
#  'Dr. Dyt. ': 1}

# %%
number_of_examples_per_class = {}

for i in classes:
    number_of_examples_per_class[i] = len(df[df['doctor_speciality'] == i])

print("Number of examples per class"), number_of_examples_per_class
# Out:
# Number of examples per class
# (None,
#  {'cerrahi': 57462,
#   'dermatoloji': 3985,
#   'kadın-dogum': 67286,
#   'diyetisyen': 1620,
#   'fizik-tedavi-ve-rehabilitasyon': 5405,
#   'dahiliye': 17426,
#   'göz': 2382,
#   'psikiyatri-ve-psikoloji': 6702,
#   'anestezi-ve-algoloji': 2115,
#   'acil-tip': 103,
#   'kardiyoloji': 2637,
#   'diş-hekimliği': 3966,
#   'genetik': 224,
#   'göğüs-hastaliklari': 679,
#   'kulak-burun-bogaz': 5270,
#   'farmakoloji': 1449,
#   'veterinerlik': 684,
#   'enfeksiyon-ve-immunoloji': 1508,
#   'biyokimya': 42,
#   'noroloji': 3672,
#   'geleneksel-tamamlayici-tip': 336,
#   'radyoloji-ve-onkoloji': 1776,
#   'patoloji': 667,
#   'spor-hekimliği': 56,
#   'anatomi-ve-histoloji': 46,
#   'çocuk-gelişimi': 75,
#   'konuşma-terapisi': 59})

# %%
# new_df just has 2 doctor_speciality classes 0 and 2
new_df = df[(df['doctor_speciality'] == 'cerrahi') | (df['doctor_speciality'] == 'kadın-dogum')]
new_df['doctor_speciality'] = new_df['doctor_speciality'].apply(lambda x: 0 if x == 'cerrahi' else 1)
# 0 is cerrahi and 1 is kadın-dogum
new_df
# Out:
# /var/folders/gs/crm1zcvj00j1kl0l1lvz4qf40000gn/T/ipykernel_38061/3133399908.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['doctor_speciality'] = new_df['doctor_speciality'].apply(lambda x: 0 if x == 'cerrahi' else 1)
#         doctor_title  doctor_speciality  \
# 0                  7                  0
# 2                  6                  0
# 3                  6                  0
# 4                  6                  1
# 6                  6                  1
# ...              ...                ...
# 187626             6                  0
# 187627             6                  1
# 187628             6                  0
# 187629             6                  1
# 187630             8                  0
#
#                                          question_content  \
# 0       Merhaba, Yaklaşık 4 aydır sağ omuzumda kolumu ...
# 2       Hocam merhaba 29 yaşında erkek hasta hareketle...
# 3       Meraba hocam sorum şu , bir erkek bayıltılıp a...
# 4       Merhaba doktor hanim ben 3 yildir evliyim. Hic...
# 6       Merhaba.. Benim size sorum olacakti .. Ben 3 s...
# ...                                                   ...
# 187626  Merhaba L3 4 L4 5 duzeyınde anular buldıng ızl...
# 187627  hocam merhaba , son kontrolüme göre gebelik ha...
# 187628  Hocam 15 yildir basur sikintisi çeken biriyim ...
# 187629  hocam öncelikle meraba ortalama 3 yıl önce kad...
# 187630  Merhaba hocam testis kanseri olan hastalarda k...
#
#                                           question_answer
# 0       Merhabalar geçmiş olsun mr raporuna göre omzum...
# 2       Şikayetinizin daha iyi anlaşılabilmesi için mu...
# 3       Bir kimseye tecavüz edilmişse anal mukozada ir...
# 4       Merhaba tiroıd bezinin düzenli çalışmaması geb...
# 6       Ara verip devam edebilirsiniz bazı polkistik o...
# ...                                                   ...
# 187626  MR raporunuza göre acil ameliyatlık bir durum ...
# 187627  tek nir bpd ölçülerek bebek hakkında olumsuzlu...
# 187628  tuvalete gitmediğiniz sürece kanama olmaması b...
# 187629  Mrhaba bu grup ilaçlar adeti kesebiliyor,tekra...
# 187630                 Çok seyrek görülen bir belirtidir.
#
# [124748 rows x 4 columns]

# %%
new_df.to_csv('new_df.csv', index=False)
import pandas as pd
new_df = pd.read_csv('new_df.csv')
new_df
# Out:
#         doctor_title  doctor_speciality  \
# 0                  7                  0
# 1                  6                  0
# 2                  6                  0
# 3                  6                  1
# 4                  6                  1
# ...              ...                ...
# 124743             6                  0
# 124744             6                  1
# 124745             6                  0
# 124746             6                  1
# 124747             8                  0
#
#                                          question_content  \
# 0       Merhaba, Yaklaşık 4 aydır sağ omuzumda kolumu ...
# 1       Hocam merhaba 29 yaşında erkek hasta hareketle...
# 2       Meraba hocam sorum şu , bir erkek bayıltılıp a...
# 3       Merhaba doktor hanim ben 3 yildir evliyim. Hic...
# 4       Merhaba.. Benim size sorum olacakti .. Ben 3 s...
# ...                                                   ...
# 124743  Merhaba L3 4 L4 5 duzeyınde anular buldıng ızl...
# 124744  hocam merhaba , son kontrolüme göre gebelik ha...
# 124745  Hocam 15 yildir basur sikintisi çeken biriyim ...
# 124746  hocam öncelikle meraba ortalama 3 yıl önce kad...
# 124747  Merhaba hocam testis kanseri olan hastalarda k...
#
#                                           question_answer
# 0       Merhabalar geçmiş olsun mr raporuna göre omzum...
# 1       Şikayetinizin daha iyi anlaşılabilmesi için mu...
# 2       Bir kimseye tecavüz edilmişse anal mukozada ir...
# 3       Merhaba tiroıd bezinin düzenli çalışmaması geb...
# 4       Ara verip devam edebilirsiniz bazı polkistik o...
# ...                                                   ...
# 124743  MR raporunuza göre acil ameliyatlık bir durum ...
# 124744  tek nir bpd ölçülerek bebek hakkında olumsuzlu...
# 124745  tuvalete gitmediğiniz sürece kanama olmaması b...
# 124746  Mrhaba bu grup ilaçlar adeti kesebiliyor,tekra...
# 124747                 Çok seyrek görülen bir belirtidir.
#
# [124748 rows x 4 columns]

# %%
import torch.nn as nn

class BinaryClassifier(nn.Module):
    def __init__(self, embedding_dim=768):
        super(BinaryClassifier, self).__init__()
        self.fc = nn.Linear(embedding_dim, 1)  # Single output neuron for binary classification

    def forward(self, x):
        return self.fc(x)  # Output will be used with BCEWithLogitsLoss

# %%
import torch.optim as optim

class CustomOptimizer:
    def __init__(self, model, base_lr=1e-3):
        self.model = model
        self.base_lr = base_lr
        self.optimizer = optim.Adam(model.parameters(), lr=base_lr)

    def step(self, batch_reliability_scores):
        # Update learning rate based on reliability score of the batch
        for idx, param_group in enumerate(self.optimizer.param_groups):
            # Scale base_lr by the mean reliability score of the batch
            param_group['lr'] = self.base_lr * batch_reliability_scores.mean().item()

        self.optimizer.step()
        self.optimizer.zero_grad()

# %%
# Initialize the loss function
criterion = nn.BCEWithLogitsLoss()

# %%
# Hyperparameters
embedding_dim = 768
base_lr = 1e-3

# Initialize the model and custom optimizer
model = BinaryClassifier(embedding_dim=embedding_dim).to(device)
custom_optimizer = CustomOptimizer(model, base_lr=base_lr)

# %%
from torch.utils.data import Dataset

class CustomDataset(Dataset):
    def __init__(self, embeddings, labels, reliability_scores):
        self.embeddings = embeddings
        self.labels = labels
        self.reliability_scores = reliability_scores

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        embedding = self.embeddings[idx]
        label = self.labels[idx]
        reliability_score = self.reliability_scores[idx]
        
        return embedding, label, reliability_score

# %%
len(embed_text("Merhaba, benim adım Ali. Bugün hava çok güzel."))
# Out:
# 768

# %%
""" # Convert question embeddings to a list of tensors
embeddings = torch.stack(df['embedding'].tolist())
labels = torch.tensor(df['doctor_speciality'].values)  # Assuming binary classes (0 or 1)
reliability_scores = torch.tensor(df['doctor_title'].values).float()  # Doctor titles as reliability scores
 """
embeddings_list = []
labels_list = []
reliability_scores_list = []
for i, row in new_df.iterrows():
  text = row['question_content'] + " " + row['question_answer']
  embedding = embed_text(text)
  embeddings_list.append(embedding)
  labels_list.append(row['doctor_speciality'])
  reliability_scores_list.append(row['doctor_title'] / 5)
  print(i, row['doctor_title'] / 5, row['doctor_speciality'], len(embedding))

embeddings = torch.stack(embeddings_list)
labels = torch.tensor(labels_list)
reliability_scores = torch.tensor(reliability_scores_list).float()

embeddings.shape, labels.shape, reliability_scores.shape
# Out:
# 0 1.4 0 768
# 1 1.2 0 768
# 2 1.2 0 768
# 3 1.2 1 768
# 4 1.2 1 768
# 5 1.2 0 768
# 6 1.6 0 768
# 7 1.2 1 768
# 8 2.0 0 768
# 9 2.0 0 768
# 10 2.0 1 768
# 11 1.2 0 768
# 12 1.2 1 768
# 13 2.0 0 768
# 14 1.2 1 768
# 15 1.2 0 768
# 16 1.2 1 768
# 17 2.0 0 768
# 18 2.0 1 768
# 19 2.0 1 768
# 20 1.2 1 768
# 21 1.6 0 768
# 22 1.6 1 768
# 23 2.0 1 768
# 24 1.2 1 768
# 25 1.2 1 768
# 26 1.2 0 768
# 27 2.0 0 768
# 28 2.0 1 768
# 29 2.0 1 768
# 30 1.2 1 768
# 31 1.2 0 768
# 32 1.6 0 768
# 33 1.2 0 768
# 34 1.2 0 768
# 35 2.0 0 768
# 36 1.2 0 768
# 37 1.2 1 768
# 38 1.2 1 768
# 39 1.2 0 768
# 40 2.0 0 768
# 41 1.2 0 768
# 42 2.0 0 768
# 43 1.2 1 768
# 44 1.2 1 768
# 45 2.0 1 768
# 46 2.0 0 768
# 47 1.6 1 768
# 48 1.2 1 768
# 49 2.0 1 768
# 50 2.0 0 768
# 51 1.2 1 768
# 52 1.2 1 768
# 53 2.0 1 768
# 54 1.2 1 768
# 55 2.0 0 768
# 56 1.2 0 768
# 57 2.0 1 768
# 58 1.2 0 768
# 59 2.0 0 768
# 60 2.0 0 768
# 61 2.0 1 768
# 62 2.0 1 768
# 63 1.2 0 768
# 64 1.2 1 768
# 65 2.0 0 768
# 66 1.2 1 768
# 67 1.2 0 768
# 68 1.2 1 768
# 69 1.2 0 768
# 70 2.0 1 768
# 71 1.2 0 768
# 72 2.0 1 768
# 73 1.2 0 768
# 74 1.6 0 768
# 75 2.0 0 768
# 76 2.0 1 768
# 77 1.2 1 768
# 78 2.0 0 768
# 79 1.2 1 768
# 80 1.2 1 768
# 81 2.0 0 768
# 82 2.0 0 768
# 83 1.2 1 768
# 84 1.2 1 768
# 85 1.2 1 768
# 86 1.6 1 768
# 87 1.2 1 768
# 88 2.0 1 768
# 89 2.0 1 768
# 90 1.2 1 768
# 91 1.2 1 768
# 92 1.2 1 768
# 93 1.2 1 768
# 94 1.2 1 768
# 95 2.0 0 768
# 96 2.0 1 768
# 97 1.0 1 768
# 98 1.2 0 768
# 99 2.0 1 768
# 100 1.2 0 768
# 101 2.0 0 768
# 102 1.2 0 768
# 103 1.2 0 768
# 104 2.0 1 768
# 105 1.2 1 768
# 106 1.2 1 768
# 107 1.2 1 768
# 108 1.2 1 768
# 109 1.2 1 768
# 110 1.2 1 768
# 111 1.2 0 768
# 112 1.6 1 768
# 113 2.0 0 768
# 114 2.0 0 768
# 115 1.4 1 768
# 116 1.2 0 768
# 117 1.2 1 768
# 118 1.2 0 768
# 119 1.2 1 768
# 120 2.0 1 768
# 121 1.2 0 768
# 122 2.0 1 768
# 123 2.0 1 768
# 124 1.2 0 768
# 125 1.2 1 768
# 126 1.2 0 768
# 127 2.0 1 768
# 128 1.2 1 768
# 129 2.0 1 768
# 130 1.2 0 768
# 131 1.2 1 768
# 132 1.2 1 768
# 133 2.0 0 768
# 134 1.2 1 768
# 135 1.2 0 768
# 136 2.0 0 768
# 137 1.2 1 768
# 138 2.0 1 768
# 139 2.0 0 768
# 140 2.0 1 768
# 141 2.0 0 768
# 142 1.6 0 768
# 143 2.0 0 768
# 144 1.2 1 768
# 145 1.2 1 768
# 146 1.2 0 768
# 147 1.2 1 768
# 148 1.4 1 768
# 149 1.2 1 768
# 150 1.6 0 768
# 151 2.0 1 768
# 152 1.2 1 768
# 153 1.2 1 768
# 154 1.2 1 768
# 155 2.0 1 768
# 156 1.2 1 768
# 157 1.6 0 768
# 158 1.2 1 768
# 159 2.0 0 768
# 160 1.2 0 768
# 161 1.2 0 768
# 162 2.0 0 768
# 163 2.0 0 768
# 164 1.2 1 768
# 165 1.6 0 768
# 166 2.0 0 768
# 167 2.0 1 768
# 168 1.2 1 768
# 169 1.2 1 768
# 170 1.2 0 768
# 171 2.0 1 768
# 172 1.2 1 768
# 173 2.0 0 768
# 174 1.2 1 768
# 175 2.0 1 768
# 176 1.2 1 768
# 177 1.2 1 768
# 178 1.6 0 768
# 179 1.6 0 768
# 180 1.2 1 768
# 181 1.2 0 768
# 182 2.0 0 768
# 183 1.2 1 768
# 184 1.2 0 768
# 185 2.0 1 768
# 186 1.4 0 768
# 187 1.2 1 768
# 188 2.0 1 768
# 189 2.0 0 768
# 190 2.0 0 768
# 191 1.2 1 768
# 192 2.0 1 768
# 193 2.0 1 768
# 194 1.2 0 768
# 195 1.2 1 768
# 196 1.2 0 768
# 197 2.0 1 768
# 198 1.2 0 768
# 199 1.2 1 768
# 200 1.2 1 768
# 201 1.2 1 768
# 202 2.0 0 768
# 203 2.0 0 768
# 204 1.2 0 768
# 205 2.0 1 768
# 206 2.0 0 768
# 207 1.6 0 768
# 208 1.2 1 768
# 209 1.6 0 768
# 210 1.2 0 768
# 211 1.2 1 768
# 212 1.2 1 768
# 213 1.6 0 768
# 214 1.2 0 768
# 215 1.2 1 768
# 216 1.2 1 768
# 217 1.6 0 768
# 218 1.6 0 768
# 219 1.2 1 768
# 220 2.0 0 768
# 221 2.0 1 768
# 222 2.0 0 768
# 223 1.2 0 768
# 224 1.2 1 768
# 225 1.2 0 768
# 226 2.0 0 768
# 227 2.0 0 768
# 228 2.0 0 768
# 229 2.0 0 768
# 230 1.2 0 768
# 231 1.2 1 768
# 232 1.0 1 768
# 233 2.0 0 768
# 234 1.2 1 768
# 235 1.2 1 768
# 236 1.2 0 768
# 237 1.2 1 768
# 238 1.2 0 768
# 239 1.6 0 768
# 240 1.6 0 768
# 241 1.2 0 768
# 242 1.6 0 768
# 243 2.0 0 768
# 244 1.2 1 768
# 245 1.6 0 768
# 246 1.6 1 768
# 247 1.2 1 768
# 248 1.6 0 768
# 249 1.2 1 768
# 250 1.6 0 768
# 251 1.2 1 768
# 252 1.2 0 768
# 253 1.2 0 768
# 254 2.0 0 768
# 255 1.2 0 768
# 256 1.2 0 768
# 257 1.2 1 768
# 258 1.2 0 768
# 259 2.0 1 768
# 260 1.6 0 768
# 261 1.2 1 768
# 262 1.2 0 768
# 263 1.2 0 768
# 264 1.2 1 768
# 265 1.2 0 768
# 266 1.6 1 768
# 267 1.2 1 768
# 268 1.2 1 768
# 269 1.2 0 768
# 270 2.0 0 768
# 271 1.2 1 768
# 272 1.2 0 768
# 273 1.2 0 768
# 274 1.2 1 768
# 275 1.2 1 768
# 276 2.0 0 768
# 277 1.2 1 768
# 278 2.0 1 768
# 279 1.2 1 768
# 280 2.0 0 768
# 281 2.0 0 768
# 282 1.2 1 768
# 283 1.6 0 768
# 284 1.6 1 768
# 285 1.6 0 768
# 286 1.2 0 768
# 287 1.2 1 768
# 288 2.0 0 768
# 289 1.2 1 768
# 290 1.2 1 768
# 291 2.0 0 768
# 292 1.6 1 768
# 293 1.2 1 768
# 294 2.0 0 768
# 295 1.2 0 768
# 296 1.4 1 768
# 297 1.2 0 768
# 298 2.0 1 768
# 299 1.2 1 768
# 300 1.2 1 768
# 301 1.2 0 768
# 302 1.6 0 768
# 303 1.2 1 768
# 304 1.6 1 768
# 305 1.2 1 768
# 306 2.0 0 768
# 307 2.0 1 768
# 308 1.6 0 768
# 309 2.0 0 768
# 310 1.2 1 768
# 311 1.6 0 768
# 312 1.2 1 768
# 313 1.6 0 768
# 314 1.2 1 768
# 315 1.6 0 768
# 316 2.0 1 768
# 317 2.0 0 768
# 318 2.0 0 768
# 319 1.6 0 768
# 320 1.2 1 768
# 321 1.2 1 768
# 322 2.0 1 768
# 323 2.0 0 768
# 324 1.2 0 768
# 325 1.2 0 768
# 326 1.2 1 768
# 327 1.2 1 768
# 328 2.0 0 768
# 329 1.2 0 768
# 330 1.2 0 768
# 331 1.2 1 768
# 332 1.6 0 768
# 333 1.2 1 768
# 334 1.6 0 768
# 335 1.2 0 768
# 336 2.0 1 768
# 337 1.2 0 768
# 338 1.2 1 768
# 339 1.2 1 768
# 340 1.2 0 768
# 341 1.2 1 768
# 342 1.2 1 768
# 343 1.2 1 768
# 344 1.2 1 768
# 345 2.0 1 768
# 346 1.4 1 768
# 347 1.2 0 768
# 348 2.0 1 768
# 349 2.0 1 768
# 350 2.0 0 768
# 351 2.0 1 768
# 352 1.2 0 768
# 353 1.2 0 768
# 354 1.2 0 768
# 355 2.0 1 768
# 356 1.2 0 768
# 357 1.2 0 768
# 358 2.0 0 768
# 359 1.2 1 768
# 360 1.2 0 768
# 361 2.0 0 768
# 362 1.2 0 768
# 363 1.2 1 768
# 364 1.2 0 768
# 365 1.2 1 768
# 366 2.0 0 768
# 367 2.0 1 768
# 368 1.2 0 768
# 369 2.0 1 768
# 370 1.2 1 768
# 371 2.0 1 768
# 372 1.2 0 768
# 373 1.6 0 768
# 374 1.2 1 768
# 375 1.2 0 768
# 376 1.2 1 768
# 377 1.2 1 768
# 378 1.2 1 768
# 379 2.0 0 768
# 380 1.6 0 768
# 381 1.2 0 768
# 382 1.2 1 768
# 383 2.0 0 768
# 384 1.2 1 768
# 385 1.2 1 768
# 386 1.2 1 768
# 387 1.2 1 768
# 388 2.0 1 768
# 389 2.0 0 768
# 390 2.0 0 768
# 391 1.4 0 768
# 392 1.2 1 768
# 393 1.6 0 768
# 394 1.2 0 768
# 395 2.0 0 768
# 396 1.2 1 768
# 397 2.0 0 768
# 398 1.6 1 768
# 399 2.0 0 768
# 400 1.2 0 768
# 401 2.0 0 768
# 402 1.2 1 768
# 403 1.2 1 768
# 404 2.0 1 768
# 405 1.6 0 768
# 406 1.4 1 768
# 407 1.2 1 768
# 408 1.2 1 768
# 409 1.2 0 768
# 410 1.6 0 768
# 411 1.2 0 768
# 412 1.2 1 768
# 413 1.2 0 768
# 414 1.4 1 768
# 415 2.0 0 768
# 416 1.2 1 768
# 417 2.0 0 768
# 418 2.0 1 768
# 419 2.0 0 768
# 420 1.6 0 768
# 421 1.2 0 768
# 422 1.2 1 768
# 423 2.0 1 768
# 424 1.2 1 768
# 425 2.0 1 768
# 426 2.0 1 768
# 427 2.0 0 768
# 428 2.0 1 768
# 429 1.2 1 768
# 430 1.6 0 768
# 431 1.2 1 768
# 432 1.2 0 768
# 433 2.0 0 768
# 434 1.4 0 768
# 435 1.2 1 768
# 436 1.2 0 768
# 437 2.0 1 768
# 438 1.2 1 768
# 439 2.0 1 768
# 440 1.2 1 768
# 441 1.2 0 768
# 442 1.2 1 768
# 443 1.6 0 768
# 444 1.2 1 768
# 445 1.2 1 768
# 446 1.2 1 768
# 447 1.2 1 768
# 448 1.2 1 768
# 449 1.2 0 768
# 450 1.2 0 768
# 451 1.6 0 768
# 452 1.2 1 768
# 453 1.2 0 768
# 454 1.2 1 768
# 455 1.2 1 768
# 456 1.2 0 768
# 457 1.2 1 768
# 458 1.2 0 768
# 459 1.2 1 768
# 460 1.2 1 768
# 461 2.0 1 768
# 462 2.0 1 768
# 463 1.2 1 768
# 464 1.2 0 768
# 465 1.6 0 768
# 466 1.6 0 768
# 467 1.2 1 768
# 468 1.2 1 768
# 469 1.2 1 768
# 470 1.2 1 768
# 471 1.2 1 768
# 472 1.2 0 768
# 473 1.2 1 768
# 474 1.2 0 768
# 475 2.0 0 768
# 476 1.2 0 768
# 477 1.2 0 768
# 478 1.2 1 768
# 479 1.2 1 768
# 480 1.2 1 768
# 481 1.2 0 768
# 482 2.0 1 768
# 483 1.2 1 768
# 484 2.0 1 768
# 485 1.2 0 768
# 486 1.6 0 768
# 487 1.2 0 768
# 488 1.2 1 768
# 489 2.0 0 768
# 490 1.6 0 768
# 491 2.0 1 768
# 492 1.2 0 768
# 493 1.2 1 768
# 494 1.2 1 768
# 495 2.0 0 768
# 496 1.2 1 768
# 497 1.2 0 768
# 498 1.6 0 768
# 499 1.2 0 768
# 500 1.2 1 768
# 501 1.2 0 768
# 502 1.2 0 768
# 503 1.2 1 768
# 504 2.0 0 768
# 505 1.2 1 768
# 506 2.0 1 768
# 507 1.2 0 768
# 508 2.0 0 768
# 509 1.6 0 768
# 510 1.6 1 768
# 511 2.0 0 768
# 512 2.0 1 768
# 513 1.2 1 768
# 514 1.2 0 768
# 515 2.0 0 768
# 516 1.2 0 768
# 517 2.0 1 768
# 518 2.0 0 768
# 519 1.2 1 768
# 520 1.2 1 768
# 521 2.0 1 768
# 522 1.2 0 768
# 523 1.2 0 768
# 524 1.2 1 768
# 525 1.2 1 768
# 526 1.2 1 768
# 527 1.2 1 768
# 528 1.2 0 768
# 529 1.2 1 768
# 530 1.2 1 768
# 531 1.2 0 768
# 532 1.2 0 768
# 533 1.2 1 768
# 534 1.0 1 768
# 535 1.2 0 768
# 536 1.2 1 768
# 537 2.0 0 768
# 538 1.2 1 768
# 539 1.6 0 768
# 540 1.2 1 768
# 541 2.0 1 768
# 542 1.2 1 768
# 543 1.2 1 768
# 544 1.6 0 768
# 545 1.2 0 768
# 546 1.6 0 768
# 547 1.2 1 768
# 548 1.2 0 768
# 549 2.0 1 768
# 550 1.6 0 768
# 551 1.2 0 768
# 552 2.0 1 768
# 553 1.2 1 768
# 554 1.4 1 768
# 555 2.0 1 768
# 556 1.2 1 768
# 557 1.2 0 768
# 558 2.0 1 768
# 559 2.0 0 768
# 560 2.0 0 768
# 561 2.0 0 768
# 562 1.2 1 768
# 563 1.2 0 768
# 564 1.2 0 768
# 565 1.2 1 768
# 566 1.2 1 768
# 567 1.2 0 768
# 568 1.2 1 768
# 569 1.2 1 768
# 570 2.0 0 768
# 571 2.0 0 768
# 572 2.0 1 768
# 573 1.2 0 768
# 574 2.0 0 768
# 575 1.2 1 768
# 576 1.4 1 768
# 577 2.0 0 768
# 578 1.2 0 768
# 579 2.0 1 768
# 580 1.2 0 768
# 581 1.2 0 768
# 582 2.0 0 768
# 583 1.2 1 768
# 584 1.2 1 768
# 585 1.2 1 768
# 586 1.6 1 768
# 587 1.2 0 768
# 588 1.2 1 768
# 589 1.2 1 768
# 590 1.2 1 768
# 591 1.2 1 768
# 592 1.2 1 768
# 593 1.2 1 768
# 594 1.6 0 768
# 595 1.2 1 768
# 596 1.2 0 768
# 597 2.0 0 768
# 598 1.2 1 768
# 599 1.2 0 768
# 600 1.2 1 768
# 601 2.0 0 768
# 602 1.6 0 768
# 603 1.2 1 768
# 604 1.2 0 768
# 605 2.0 0 768
# 606 1.2 1 768
# 607 2.0 0 768
# 608 1.2 1 768
# 609 2.0 0 768
# 610 2.0 1 768
# 611 1.2 1 768
# 612 1.2 0 768
# 613 1.2 0 768
# 614 2.0 1 768
# 615 1.2 0 768
# 616 1.2 0 768
# 617 1.6 0 768
# 618 2.0 1 768
# 619 1.2 1 768
# 620 2.0 0 768
# 621 2.0 1 768
# 622 2.0 1 768
# 623 2.0 0 768
# 624 1.2 1 768
# 625 1.6 0 768
# 626 2.0 1 768
# 627 1.2 1 768
# 628 1.2 0 768
# 629 1.6 0 768
# 630 2.0 0 768
# 631 1.2 1 768
# 632 1.2 1 768
# 633 1.6 0 768
# 634 1.2 1 768
# 635 1.2 1 768
# 636 1.2 0 768
# 637 1.2 1 768
# 638 2.0 0 768
# 639 1.2 0 768
# 640 1.2 1 768
# 641 1.2 0 768
# 642 2.0 0 768
# 643 1.2 0 768
# 644 1.2 1 768
# 645 1.4 0 768
# 646 1.2 0 768
# 647 2.0 1 768
# 648 2.0 1 768
# 649 1.6 0 768
# 650 2.0 1 768
# 651 1.2 1 768
# 652 1.2 1 768
# 653 1.6 0 768
# 654 2.0 0 768
# 655 1.2 1 768
# 656 2.0 1 768
# 657 1.2 1 768
# 658 1.4 0 768
# 659 2.0 0 768
# 660 2.0 1 768
# 661 2.0 1 768
# 662 1.2 0 768
# 663 2.0 1 768
# 664 2.0 0 768
# 665 2.0 1 768
# 666 1.2 0 768
# 667 1.2 0 768
# 668 2.0 0 768
# 669 1.2 1 768
# 670 1.2 0 768
# 671 2.0 1 768
# 672 2.0 1 768
# 673 1.2 0 768
# 674 1.2 0 768
# 675 1.6 0 768
# 676 2.0 0 768
# 677 2.0 1 768
# 678 2.0 0 768
# 679 1.2 0 768
# 680 1.2 1 768
# 681 1.2 1 768
# 682 1.2 1 768
# 683 1.2 0 768
# 684 1.2 1 768
# 685 1.2 0 768
# 686 2.0 1 768
# 687 2.0 0 768
# 688 1.2 1 768
# 689 1.2 0 768
# 690 1.2 1 768
# 691 1.2 0 768
# 692 1.2 0 768
# 693 1.6 1 768
# 694 1.2 1 768
# 695 2.0 0 768
# 696 1.2 0 768
# 697 1.2 1 768
# 698 2.0 0 768
# 699 1.2 1 768
# 700 1.4 1 768
# 701 1.2 1 768
# 702 1.2 0 768
# 703 2.0 1 768
# 704 1.6 0 768
# 705 1.2 1 768
# 706 1.2 1 768
# 707 2.0 0 768
# 708 1.2 1 768
# 709 2.0 1 768
# 710 2.0 0 768
# 711 1.6 1 768
# 712 1.2 0 768
# 713 1.2 0 768
# 714 2.0 1 768
# 715 1.2 0 768
# 716 1.2 0 768
# 717 1.6 0 768
# 718 1.2 0 768
# 719 1.2 0 768
# 720 2.0 0 768
# 721 1.2 1 768
# 722 1.6 0 768
# 723 1.6 0 768
# 724 1.2 1 768
# 725 1.2 1 768
# 726 1.2 1 768
# 727 1.2 0 768
# 728 2.0 1 768
# 729 1.2 0 768
# 730 2.0 0 768
# 731 2.0 0 768
# 732 1.6 0 768
# 733 1.2 1 768
# 734 1.4 1 768
# 735 2.0 1 768
# 736 2.0 1 768
# 737 1.2 1 768
# 738 1.2 0 768
# 739 1.6 0 768
# 740 1.2 1 768
# 741 2.0 1 768
# 742 1.2 1 768
# 743 1.2 0 768
# 744 2.0 1 768
# 745 2.0 1 768
# 746 1.6 1 768
# 747 2.0 1 768
# 748 2.0 1 768
# 749 2.0 0 768
# 750 2.0 1 768
# 751 1.2 1 768
# 752 1.2 1 768
# 753 1.2 0 768
# 754 1.2 0 768
# 755 1.2 1 768
# 756 1.6 0 768
# 757 2.0 1 768
# 758 2.0 1 768
# 759 1.2 1 768
# 760 1.2 1 768
# 761 2.0 0 768
# 762 2.0 1 768
# 763 1.2 0 768
# 764 1.6 0 768
# 765 1.2 1 768
# 766 1.2 1 768
# 767 1.2 1 768
# 768 1.2 0 768
# 769 2.0 0 768
# 770 2.0 0 768
# 771 1.2 1 768
# 772 1.6 0 768
# 773 1.2 1 768
# 774 1.2 1 768
# 775 2.0 1 768
# 776 2.0 1 768
# 777 1.2 1 768
# 778 2.0 1 768
# 779 1.2 1 768
# 780 1.6 0 768
# 781 2.0 0 768
# 782 1.2 1 768
# 783 1.2 0 768
# 784 1.4 1 768
# 785 1.2 1 768
# 786 2.0 0 768
# 787 2.0 1 768
# 788 2.0 1 768
# 789 1.2 1 768
# 790 1.2 0 768
# 791 2.0 0 768
# 792 1.2 0 768
# 793 2.0 0 768
# 794 2.0 0 768
# 795 1.2 0 768
# 796 1.2 0 768
# 797 2.0 0 768
# 798 1.6 0 768
# 799 2.0 1 768
# 800 2.0 0 768
# 801 2.0 0 768
# 802 1.2 1 768
# 803 1.2 0 768
# 804 1.2 0 768
# 805 2.0 0 768
# 806 2.0 0 768
# 807 1.2 1 768
# 808 1.2 0 768
# 809 1.2 0 768
# 810 2.0 0 768
# 811 1.2 1 768
# 812 1.2 1 768
# 813 2.0 0 768
# 814 1.6 0 768
# 815 2.0 1 768
# 816 1.2 1 768
# 817 1.2 0 768
# 818 1.2 0 768
# 819 2.0 0 768
# 820 1.2 0 768
# 821 1.6 0 768
# 822 1.6 0 768
# 823 1.2 1 768
# 824 1.4 1 768
# 825 1.6 0 768
# 826 1.2 0 768
# 827 1.2 0 768
# 828 2.0 1 768
# 829 1.2 1 768
# 830 1.2 1 768
# 831 1.6 0 768
# 832 2.0 1 768
# 833 1.4 1 768
# 834 1.2 1 768
# 835 2.0 1 768
# 836 2.0 1 768
# 837 2.0 0 768
# 838 2.0 0 768
# 839 1.2 1 768
# 840 2.0 0 768
# 841 2.0 1 768
# 842 1.2 1 768
# 843 1.2 1 768
# 844 1.6 0 768
# 845 1.2 1 768
# 846 2.0 1 768
# 847 2.0 0 768
# 848 1.2 1 768
# 849 1.2 1 768
# 850 1.6 0 768
# 851 1.2 0 768
# 852 1.2 1 768
# 853 2.0 0 768
# 854 1.2 0 768
# 855 1.2 0 768
# 856 2.0 1 768
# 857 1.6 0 768
# 858 1.2 0 768
# 859 2.0 1 768
# 860 1.2 1 768
# 861 1.2 1 768
# 862 1.6 0 768
# 863 1.4 1 768
# 864 1.2 1 768
# 865 1.2 1 768
# 866 2.0 0 768
# 867 1.6 0 768
# 868 1.6 0 768
# 869 1.2 1 768
# 870 2.0 1 768
# 871 1.2 0 768
# 872 1.2 1 768
# 873 1.2 0 768
# 874 1.2 1 768
# 875 1.6 1 768
# 876 1.2 0 768
# 877 1.2 1 768
# 878 1.6 0 768
# 879 2.0 0 768
# 880 1.2 0 768
# 881 1.2 1 768
# 882 1.4 0 768
# 883 2.0 1 768
# 884 2.0 1 768
# 885 1.2 0 768
# 886 1.2 1 768
# 887 2.0 0 768
# 888 1.2 0 768
# 889 1.6 0 768
# 890 1.2 0 768
# 891 1.4 0 768
# 892 1.2 1 768
# 893 1.6 0 768
# 894 1.2 1 768
# 895 2.0 1 768
# 896 2.0 1 768
# 897 1.2 1 768
# 898 1.2 0 768
# 899 1.2 1 768
# 900 1.2 1 768
# 901 2.0 0 768
# 902 1.2 0 768
# 903 1.4 1 768
# 904 1.2 1 768
# 905 2.0 0 768
# 906 1.2 0 768
# 907 2.0 0 768
# 908 1.2 1 768
# 909 2.0 0 768
# 910 1.2 1 768
# 911 1.2 1 768
# 912 1.2 0 768
# 913 2.0 0 768
# 914 1.2 1 768
# 915 2.0 0 768
# 916 1.2 1 768
# 917 1.2 0 768
# 918 1.2 1 768
# 919 2.0 0 768
# 920 2.0 0 768
# 921 1.2 0 768
# 922 1.2 1 768
# 923 2.0 1 768
# 924 1.2 1 768
# 925 1.6 0 768
# 926 1.6 0 768
# 927 1.2 0 768
# 928 2.0 1 768
# 929 1.2 0 768
# 930 1.2 1 768
# 931 1.2 1 768
# 932 1.2 1 768
# 933 1.2 1 768
# 934 1.2 1 768
# 935 1.2 1 768
# 936 2.0 0 768
# 937 2.0 0 768
# 938 2.0 1 768
# 939 2.0 1 768
# 940 2.0 0 768
# 941 2.0 0 768
# 942 1.2 0 768
# 943 2.0 1 768
# 944 1.2 1 768
# 945 2.0 0 768
# 946 1.2 1 768
# 947 1.2 1 768
# 948 1.2 1 768
# 949 1.2 0 768
# 950 1.6 0 768
# 951 1.2 1 768
# 952 2.0 0 768
# 953 2.0 1 768
# 954 1.2 0 768
# 955 2.0 1 768
# 956 1.2 1 768
# 957 1.2 1 768
# 958 2.0 0 768
# 959 2.0 1 768
# 960 1.2 1 768
# 961 1.4 0 768
# 962 1.2 0 768
# 963 2.0 0 768
# 964 2.0 0 768
# 965 1.2 1 768
# 966 2.0 0 768
# 967 1.2 1 768
# 968 2.0 0 768
# 969 2.0 0 768
# 970 2.0 0 768
# 971 2.0 0 768
# 972 2.0 0 768
# 973 1.2 1 768
# 974 1.2 1 768
# 975 1.2 0 768
# 976 1.2 0 768
# 977 2.0 1 768
# 978 1.2 1 768
# 979 1.2 1 768
# 980 1.2 0 768
# 981 1.2 0 768
# 982 1.2 0 768
# 983 1.2 0 768
# 984 1.2 0 768
# 985 1.2 0 768
# 986 2.0 0 768
# 987 2.0 1 768
# 988 1.2 1 768
# 989 2.0 0 768
# 990 1.6 0 768
# 991 1.6 1 768
# 992 1.6 0 768
# 993 2.0 0 768
# 994 1.2 0 768
# 995 1.2 1 768
# 996 1.2 1 768
# 997 2.0 0 768
# 998 2.0 1 768
# 999 1.2 1 768
# 1000 2.0 0 768
# 1001 1.2 0 768
# 1002 2.0 0 768
# 1003 1.2 0 768
# 1004 1.2 1 768
# 1005 2.0 0 768
# 1006 2.0 0 768
# 1007 2.0 1 768
# 1008 1.2 1 768
# 1009 1.4 0 768
# 1010 1.6 0 768
# 1011 2.0 0 768
# 1012 2.0 0 768
# 1013 2.0 0 768
# 1014 1.6 0 768
# 1015 1.2 1 768
# 1016 2.0 1 768
# 1017 1.2 0 768
# 1018 1.2 1 768
# 1019 1.2 1 768
# 1020 1.2 1 768
# 1021 1.2 0 768
# 1022 2.0 0 768
# 1023 1.2 0 768
# 1024 1.2 1 768
# 1025 2.0 1 768
# 1026 2.0 0 768
# 1027 1.2 0 768
# 1028 1.0 0 768
# 1029 2.0 1 768
# 1030 2.0 0 768
# 1031 1.2 1 768
# 1032 1.2 0 768
# 1033 2.0 0 768
# 1034 1.2 1 768
# 1035 1.2 1 768
# 1036 1.2 1 768
# 1037 2.0 1 768
# 1038 1.6 0 768
# 1039 1.2 0 768
# 1040 1.2 1 768
# 1041 2.0 0 768
# 1042 1.2 0 768
# 1043 1.2 0 768
# 1044 2.0 1 768
# 1045 1.2 1 768
# 1046 1.2 1 768
# 1047 1.2 1 768
# 1048 2.0 0 768
# 1049 1.2 1 768
# 1050 1.2 1 768
# 1051 2.0 1 768
# 1052 2.0 1 768
# 1053 1.6 0 768
# 1054 1.2 1 768
# 1055 2.0 0 768
# 1056 1.2 1 768
# 1057 1.2 0 768
# 1058 1.2 1 768
# 1059 1.2 1 768
# 1060 2.0 0 768
# 1061 1.2 0 768
# 1062 1.2 1 768
# 1063 1.2 1 768
# 1064 2.0 1 768
# 1065 2.0 1 768
# 1066 1.2 1 768
# 1067 1.6 1 768
# 1068 1.2 0 768
# 1069 1.2 1 768
# 1070 1.2 0 768
# 1071 2.0 1 768
# 1072 1.6 0 768
# 1073 1.2 1 768
# 1074 2.0 0 768
# 1075 1.2 1 768
# 1076 1.2 0 768
# 1077 1.4 1 768
# 1078 1.6 1 768
# 1079 2.0 0 768
# 1080 1.2 1 768
# 1081 1.2 1 768
# 1082 2.0 0 768
# 1083 2.0 0 768
# 1084 1.2 1 768
# 1085 2.0 1 768
# 1086 1.2 0 768
# 1087 1.2 1 768
# 1088 2.0 1 768
# 1089 1.4 1 768
# 1090 2.0 0 768
# 1091 1.2 1 768
# 1092 1.6 0 768
# 1093 1.2 0 768
# 1094 1.2 1 768
# 1095 1.2 0 768
# 1096 1.2 1 768
# 1097 1.2 1 768
# 1098 2.0 1 768
# 1099 1.2 0 768
# 1100 1.2 1 768
# 1101 2.0 1 768
# 1102 1.2 1 768
# 1103 2.0 0 768
# 1104 1.2 1 768
# 1105 2.0 1 768
# 1106 1.2 0 768
# 1107 2.0 1 768
# 1108 1.2 1 768
# 1109 2.0 1 768
# 1110 1.2 1 768
# 1111 2.0 1 768
# 1112 1.2 1 768
# 1113 2.0 0 768
# 1114 2.0 1 768
# 1115 1.2 1 768
# 1116 1.2 0 768
# 1117 2.0 1 768
# 1118 1.2 1 768
# 1119 2.0 0 768
# 1120 1.2 0 768
# 1121 1.2 0 768
# 1122 1.2 1 768
# 1123 2.0 1 768
# 1124 1.2 1 768
# 1125 2.0 0 768
# 1126 1.6 0 768
# 1127 2.0 0 768
# 1128 2.0 0 768
# 1129 1.2 1 768
# 1130 1.2 0 768
# 1131 1.2 0 768
# 1132 1.2 0 768
# 1133 1.2 1 768
# 1134 1.2 1 768
# 1135 1.2 1 768
# 1136 2.0 1 768
# 1137 1.2 1 768
# 1138 2.0 1 768
# 1139 1.2 1 768
# 1140 2.0 1 768
# 1141 1.2 0 768
# 1142 1.6 0 768
# 1143 1.0 1 768
# 1144 2.0 1 768
# 1145 1.2 0 768
# 1146 1.2 0 768
# 1147 1.2 0 768
# 1148 1.2 1 768
# 1149 1.2 1 768
# 1150 1.2 0 768
# 1151 1.2 1 768
# 1152 1.2 1 768
# 1153 2.0 0 768
# 1154 1.2 1 768
# 1155 1.6 0 768
# 1156 1.2 1 768
# 1157 1.2 1 768
# 1158 2.0 0 768
# 1159 2.0 1 768
# 1160 1.2 1 768
# 1161 1.2 1 768
# 1162 1.6 0 768
# 1163 1.2 1 768
# 1164 2.0 0 768
# 1165 2.0 0 768
# 1166 1.4 0 768
# 1167 1.6 0 768
# 1168 1.2 1 768
# 1169 1.4 1 768
# 1170 1.2 0 768
# 1171 1.2 1 768
# 1172 1.6 1 768
# 1173 1.2 1 768
# 1174 1.6 1 768
# 1175 1.6 0 768
# 1176 1.2 0 768
# 1177 2.0 1 768
# 1178 1.2 1 768
# 1179 2.0 0 768
# 1180 1.6 0 768
# 1181 1.2 0 768
# 1182 1.2 1 768
# 1183 1.2 1 768
# 1184 1.2 1 768
# 1185 1.2 1 768
# 1186 1.2 1 768
# 1187 1.2 0 768
# 1188 2.0 1 768
# 1189 2.0 1 768
# 1190 2.0 1 768
# 1191 1.2 0 768
# 1192 2.0 1 768
# 1193 2.0 0 768
# 1194 1.2 0 768
# 1195 1.2 1 768
# 1196 1.2 1 768
# 1197 1.6 0 768
# 1198 2.0 0 768
# 1199 2.0 0 768
# 1200 1.2 1 768
# 1201 1.2 1 768
# 1202 2.0 0 768
# 1203 1.2 0 768
# 1204 1.6 0 768
# 1205 1.2 1 768
# 1206 1.2 1 768
# 1207 1.2 0 768
# 1208 2.0 0 768
# 1209 1.2 1 768
# 1210 1.2 1 768
# 1211 1.2 0 768
# 1212 2.0 0 768
# 1213 2.0 0 768
# 1214 1.2 1 768
# 1215 2.0 0 768
# 1216 1.2 1 768
# 1217 1.2 1 768
# 1218 2.0 1 768
# 1219 1.2 0 768
# 1220 1.2 1 768
# 1221 1.2 1 768
# 1222 1.2 0 768
# 1223 1.6 0 768
# 1224 2.0 1 768
# 1225 1.2 1 768
# 1226 2.0 1 768
# 1227 2.0 0 768
# 1228 2.0 0 768
# 1229 1.2 1 768
# 1230 1.6 1 768
# 1231 1.2 1 768
# 1232 1.2 0 768
# 1233 1.2 1 768
# 1234 1.2 1 768
# 1235 2.0 0 768
# 1236 1.2 1 768
# 1237 1.2 1 768
# 1238 2.0 1 768
# 1239 1.2 1 768
# 1240 1.2 1 768
# 1241 2.0 0 768
# 1242 2.0 0 768
# 1243 2.0 1 768
# 1244 2.0 0 768
# 1245 1.2 0 768
# 1246 2.0 0 768
# 1247 1.2 1 768
# 1248 1.6 1 768
# 1249 2.0 1 768
# 1250 1.2 1 768
# 1251 1.2 1 768
# 1252 1.2 0 768
# 1253 1.2 1 768
# 1254 1.2 1 768
# 1255 1.2 1 768
# 1256 1.2 1 768
# 1257 2.0 0 768
# 1258 1.2 1 768
# 1259 1.2 1 768
# 1260 2.0 1 768
# 1261 2.0 0 768
# 1262 1.2 1 768
# 1263 1.2 1 768
# 1264 1.2 1 768
# 1265 1.2 1 768
# 1266 2.0 0 768
# 1267 1.2 0 768
# 1268 1.2 1 768
# 1269 1.2 1 768
# 1270 1.2 1 768
# 1271 1.6 0 768
# 1272 1.2 1 768
# 1273 1.2 0 768
# 1274 1.2 0 768
# 1275 1.6 0 768
# 1276 2.0 1 768
# 1277 1.2 1 768
# 1278 2.0 1 768
# 1279 1.2 1 768
# 1280 1.2 1 768
# 1281 2.0 0 768
# 1282 1.2 1 768
# 1283 1.2 1 768
# 1284 2.0 0 768
# 1285 1.2 0 768
# 1286 2.0 0 768
# 1287 1.2 1 768
# 1288 1.2 1 768
# 1289 1.2 0 768
# 1290 1.6 0 768
# 1291 1.2 0 768
# 1292 1.2 0 768
# 1293 1.2 1 768
# 1294 1.6 0 768
# 1295 1.2 1 768
# 1296 1.2 1 768
# 1297 1.6 1 768
# 1298 2.0 1 768
# 1299 1.2 0 768
# 1300 2.0 0 768
# 1301 2.0 1 768
# 1302 1.4 1 768
# 1303 2.0 0 768
# 1304 1.2 1 768
# 1305 1.2 1 768
# 1306 1.6 0 768
# 1307 1.2 1 768
# 1308 1.2 1 768
# 1309 2.0 1 768
# 1310 1.6 0 768
# 1311 1.2 0 768
# 1312 1.6 0 768
# 1313 2.0 0 768
# 1314 1.2 0 768
# 1315 1.2 0 768
# 1316 2.0 0 768
# 1317 2.0 1 768
# 1318 1.6 0 768
# 1319 1.2 1 768
# 1320 1.2 0 768
# 1321 2.0 1 768
# 1322 1.2 0 768
# 1323 1.2 1 768
# 1324 1.2 0 768
# 1325 2.0 0 768
# 1326 2.0 1 768
# 1327 1.2 0 768
# 1328 1.2 1 768
# 1329 1.4 1 768
# 1330 2.0 1 768
# 1331 1.2 1 768
# 1332 2.0 1 768
# 1333 2.0 0 768
# 1334 1.2 1 768
# 1335 2.0 0 768
# 1336 1.6 1 768
# 1337 1.2 1 768
# 1338 2.0 0 768
# 1339 1.2 0 768
# 1340 1.2 1 768
# 1341 1.2 1 768
# 1342 1.2 1 768
# 1343 1.2 0 768
# 1344 1.2 1 768
# 1345 1.6 0 768
# 1346 2.0 0 768
# 1347 2.0 0 768
# 1348 1.2 1 768
# 1349 1.2 1 768
# 1350 1.2 0 768
# 1351 1.2 1 768
# 1352 1.2 0 768
# 1353 1.2 0 768
# 1354 1.2 1 768
# 1355 2.0 0 768
# 1356 1.4 1 768
# 1357 1.2 1 768
# 1358 1.2 0 768
# 1359 1.2 1 768
# 1360 1.2 1 768
# 1361 2.0 0 768
# 1362 1.2 1 768
# 1363 1.6 1 768
# 1364 2.0 1 768
# 1365 2.0 0 768
# 1366 2.0 0 768
# 1367 2.0 1 768
# 1368 2.0 1 768
# 1369 2.0 0 768
# 1370 2.0 0 768
# 1371 1.2 1 768
# 1372 1.2 1 768
# 1373 1.2 1 768
# 1374 1.2 1 768
# 1375 1.2 1 768
# 1376 1.2 0 768
# 1377 1.2 1 768
# 1378 1.4 1 768
# 1379 1.2 1 768
# 1380 1.2 0 768
# 1381 2.0 0 768
# 1382 2.0 1 768
# 1383 1.2 0 768
# 1384 1.2 0 768
# 1385 2.0 1 768
# 1386 1.2 1 768
# 1387 1.2 1 768
# 1388 1.6 0 768
# 1389 1.2 1 768
# 1390 1.2 1 768
# 1391 2.0 1 768
# 1392 1.2 1 768
# 1393 1.2 1 768
# 1394 1.2 0 768
# 1395 1.2 0 768
# 1396 1.2 0 768
# 1397 1.2 0 768
# 1398 1.2 1 768
# 1399 1.2 0 768
# 1400 1.2 1 768
# 1401 1.2 1 768
# 1402 1.2 0 768
# 1403 1.2 0 768
# 1404 1.2 1 768
# 1405 2.0 1 768
# 1406 2.0 1 768
# 1407 1.6 1 768
# 1408 1.2 0 768
# 1409 1.2 1 768
# 1410 1.2 1 768
# 1411 1.2 1 768
# 1412 1.2 0 768
# 1413 2.0 1 768
# 1414 1.6 0 768
# 1415 1.2 1 768
# 1416 2.0 1 768
# 1417 2.0 1 768
# 1418 2.0 0 768
# 1419 1.2 0 768
# 1420 1.6 0 768
# 1421 2.0 1 768
# 1422 1.6 1 768
# 1423 1.2 0 768
# 1424 1.2 1 768
# 1425 2.0 0 768
# 1426 1.2 1 768
# 1427 1.2 1 768
# 1428 1.2 1 768
# 1429 2.0 1 768
# 1430 1.2 0 768
# 1431 2.0 1 768
# 1432 1.2 1 768
# 1433 1.4 1 768
# 1434 1.2 0 768
# 1435 1.2 1 768
# 1436 1.6 0 768
# 1437 1.4 1 768
# 1438 1.6 0 768
# 1439 1.6 0 768
# 1440 1.2 0 768
# 1441 2.0 0 768
# 1442 1.2 1 768
# 1443 1.2 1 768
# 1444 2.0 0 768
# 1445 1.2 1 768
# 1446 2.0 1 768
# 1447 1.2 1 768
# 1448 1.2 0 768
# 1449 1.6 0 768
# 1450 1.2 0 768
# 1451 1.4 0 768
# 1452 1.2 0 768
# 1453 1.2 1 768
# 1454 2.0 0 768
# 1455 1.2 0 768
# 1456 1.6 0 768
# 1457 2.0 1 768
# 1458 2.0 1 768
# 1459 2.0 1 768
# 1460 2.0 0 768
# 1461 1.6 0 768
# 1462 2.0 1 768
# 1463 1.2 1 768
# 1464 2.0 0 768
# 1465 1.2 0 768
# 1466 2.0 0 768
# 1467 1.2 1 768
# 1468 1.2 1 768
# 1469 1.2 1 768
# 1470 2.0 0 768
# 1471 2.0 0 768
# 1472 1.6 0 768
# 1473 2.0 0 768
# 1474 1.2 1 768
# 1475 2.0 1 768
# 1476 1.4 1 768
# 1477 1.2 1 768
# 1478 1.2 1 768
# 1479 1.2 1 768
# 1480 2.0 0 768
# 1481 1.6 0 768
# 1482 1.2 1 768
# 1483 1.2 1 768
# 1484 1.2 0 768
# 1485 1.2 0 768
# 1486 1.2 0 768
# 1487 2.0 1 768
# 1488 1.6 0 768
# 1489 2.0 0 768
# 1490 1.2 1 768
# 1491 1.2 1 768
# 1492 1.2 1 768
# 1493 2.0 0 768
# 1494 1.2 1 768
# 1495 2.0 0 768
# 1496 1.2 0 768
# 1497 1.2 1 768
# 1498 2.0 0 768
# 1499 1.2 1 768
# 1500 1.2 0 768
# 1501 1.2 1 768
# 1502 1.2 0 768
# 1503 1.2 1 768
# 1504 2.0 1 768
# 1505 1.2 1 768
# 1506 1.2 1 768
# 1507 2.0 0 768
# 1508 1.2 0 768
# 1509 1.2 1 768
# 1510 1.6 0 768
# 1511 1.2 1 768
# 1512 1.2 1 768
# 1513 2.0 0 768
# 1514 2.0 1 768
# 1515 1.2 0 768
# 1516 1.2 1 768
# 1517 2.0 1 768
# 1518 1.6 0 768
# 1519 2.0 1 768
# 1520 1.2 1 768
# 1521 2.0 1 768
# 1522 1.2 0 768
# 1523 1.2 1 768
# 1524 1.4 0 768
# 1525 2.0 0 768
# 1526 1.2 1 768
# 1527 1.2 0 768
# 1528 2.0 0 768
# 1529 1.2 1 768
# 1530 1.2 0 768
# 1531 2.0 0 768
# 1532 1.2 0 768
# 1533 1.2 0 768
# 1534 1.6 0 768
# 1535 1.4 1 768
# 1536 1.2 1 768
# 1537 1.2 1 768
# 1538 1.6 0 768
# 1539 2.0 1 768
# 1540 1.6 0 768
# 1541 2.0 0 768
# 1542 1.2 1 768
# 1543 2.0 1 768
# 1544 1.2 0 768
# 1545 2.0 0 768
# 1546 2.0 1 768
# 1547 1.2 1 768
# 1548 1.2 0 768
# 1549 1.6 0 768
# 1550 1.2 1 768
# 1551 2.0 0 768
# 1552 2.0 1 768
# 1553 1.2 1 768
# 1554 1.6 0 768
# 1555 1.6 0 768
# 1556 1.2 1 768
# 1557 1.2 1 768
# 1558 1.2 1 768
# 1559 1.2 1 768
# 1560 2.0 1 768
# 1561 2.0 0 768
# 1562 1.2 0 768
# 1563 1.2 1 768
# 1564 1.2 1 768
# 1565 1.2 0 768
# 1566 2.0 0 768
# 1567 1.2 1 768
# 1568 1.2 1 768
# 1569 1.2 0 768
# 1570 1.2 0 768
# 1571 2.0 0 768
# 1572 2.0 0 768
# 1573 1.2 1 768
# 1574 1.2 0 768
# 1575 1.2 0 768
# 1576 1.6 1 768
# 1577 1.2 1 768
# 1578 2.0 1 768
# 1579 1.2 1 768
# 1580 1.4 1 768
# 1581 2.0 0 768
# 1582 2.0 0 768
# 1583 1.2 1 768
# 1584 1.2 1 768
# 1585 2.0 1 768
# 1586 2.0 1 768
# 1587 1.2 1 768
# 1588 2.0 0 768
# 1589 1.2 0 768
# 1590 2.0 1 768
# 1591 1.2 1 768
# 1592 1.2 1 768
# 1593 1.6 0 768
# 1594 1.6 0 768
# 1595 1.2 1 768
# 1596 1.2 1 768
# 1597 2.0 0 768
# 1598 1.2 1 768
# 1599 1.2 1 768
# 1600 1.2 1 768
# 1601 1.2 0 768
# 1602 1.6 0 768
# 1603 1.2 0 768
# 1604 1.2 1 768
# 1605 1.2 1 768
# 1606 1.6 0 768
# 1607 1.2 1 768
# 1608 1.2 1 768
# 1609 2.0 0 768
# 1610 2.0 0 768
# 1611 1.6 0 768
# 1612 1.2 1 768
# 1613 1.6 0 768
# 1614 1.2 0 768
# 1615 1.2 1 768
# 1616 1.6 0 768
# 1617 1.2 0 768
# 1618 1.2 1 768
# 1619 1.2 1 768
# 1620 1.6 0 768
# 1621 1.2 1 768
# 1622 1.2 1 768
# 1623 2.0 0 768
# 1624 1.2 0 768
# 1625 2.0 1 768
# 1626 2.0 0 768
# 1627 1.2 0 768
# 1628 1.2 1 768
# 1629 1.2 0 768
# 1630 1.2 1 768
# 1631 2.0 0 768
# 1632 1.6 1 768
# 1633 1.4 1 768
# 1634 1.2 0 768
# 1635 1.6 0 768
# 1636 1.2 1 768
# 1637 1.2 1 768
# 1638 2.0 1 768
# 1639 2.0 1 768
# 1640 1.2 1 768
# 1641 1.2 1 768
# 1642 2.0 1 768
# 1643 1.6 0 768
# 1644 2.0 1 768
# 1645 1.2 1 768
# 1646 2.0 1 768
# 1647 1.6 0 768
# 1648 1.2 1 768
# 1649 1.2 1 768
# 1650 2.0 1 768
# 1651 2.0 0 768
# 1652 2.0 1 768
# 1653 1.6 0 768
# 1654 1.2 1 768
# 1655 1.2 0 768
# 1656 1.2 0 768
# 1657 1.2 1 768
# 1658 2.0 1 768
# 1659 1.2 1 768
# 1660 1.2 0 768
# 1661 1.6 0 768
# 1662 1.2 1 768
# 1663 2.0 1 768
# 1664 2.0 0 768
# 1665 2.0 1 768
# 1666 1.2 0 768
# 1667 1.2 0 768
# 1668 1.2 1 768
# 1669 1.2 0 768
# 1670 2.0 0 768
# 1671 2.0 0 768
# 1672 1.2 0 768
# 1673 1.2 1 768
# 1674 2.0 1 768
# 1675 2.0 0 768
# 1676 1.2 1 768
# 1677 1.2 0 768
# 1678 2.0 0 768
# 1679 1.2 1 768
# 1680 1.6 1 768
# 1681 1.2 1 768
# 1682 1.2 0 768
# 1683 2.0 0 768
# 1684 1.2 0 768
# 1685 1.2 0 768
# 1686 2.0 1 768
# 1687 1.2 1 768
# 1688 1.2 0 768
# 1689 1.2 1 768
# 1690 1.2 0 768
# 1691 2.0 1 768
# 1692 1.6 0 768
# 1693 1.2 0 768
# 1694 1.2 1 768
# 1695 1.2 0 768
# 1696 1.2 0 768
# 1697 1.2 1 768
# 1698 2.0 1 768
# 1699 1.6 0 768
# 1700 1.2 1 768
# 1701 1.6 0 768
# 1702 2.0 1 768
# 1703 1.6 0 768
# 1704 2.0 1 768
# 1705 1.2 1 768
# 1706 1.2 1 768
# 1707 1.2 0 768
# 1708 1.2 1 768
# 1709 1.2 0 768
# 1710 1.2 1 768
# 1711 1.2 0 768
# 1712 2.0 1 768
# 1713 2.0 1 768
# 1714 1.2 1 768
# 1715 2.0 0 768
# 1716 1.2 0 768
# 1717 1.2 0 768
# 1718 2.0 1 768
# 1719 1.2 0 768
# 1720 1.2 1 768
# 1721 2.0 0 768
# 1722 1.6 0 768
# 1723 2.0 0 768
# 1724 2.0 1 768
# 1725 1.2 1 768
# 1726 1.2 1 768
# 1727 1.2 0 768
# 1728 1.2 0 768
# 1729 2.0 0 768
# 1730 1.2 1 768
# 1731 1.2 1 768
# 1732 2.0 0 768
# 1733 1.2 0 768
# 1734 1.6 0 768
# 1735 1.6 0 768
# 1736 1.2 1 768
# 1737 1.2 0 768
# 1738 2.0 0 768
# 1739 2.0 0 768
# 1740 1.2 0 768
# 1741 1.2 1 768
# 1742 1.6 0 768
# 1743 1.2 1 768
# 1744 2.0 0 768
# 1745 2.0 1 768
# 1746 1.6 0 768
# 1747 1.2 1 768
# 1748 2.0 1 768
# 1749 1.6 0 768
# 1750 2.0 0 768
# 1751 2.0 0 768
# 1752 1.2 0 768
# 1753 1.2 0 768
# 1754 1.2 1 768
# 1755 2.0 1 768
# 1756 2.0 1 768
# 1757 1.2 0 768
# 1758 2.0 1 768
# 1759 1.2 1 768
# 1760 1.2 1 768
# 1761 1.2 0 768
# 1762 2.0 0 768
# 1763 2.0 1 768
# 1764 1.2 1 768
# 1765 1.2 1 768
# 1766 2.0 0 768
# 1767 1.2 1 768
# 1768 1.6 0 768
# 1769 1.2 1 768
# 1770 2.0 1 768
# 1771 1.2 1 768
# 1772 1.2 0 768
# 1773 2.0 1 768
# 1774 1.2 0 768
# 1775 1.2 0 768
# 1776 1.2 1 768
# 1777 1.2 1 768
# 1778 2.0 0 768
# 1779 2.0 1 768
# 1780 2.0 0 768
# 1781 1.2 1 768
# 1782 1.2 0 768
# 1783 1.2 0 768
# 1784 2.0 0 768
# 1785 1.2 1 768
# 1786 1.2 1 768
# 1787 1.2 0 768
# 1788 1.2 0 768
# 1789 2.0 0 768
# 1790 2.0 0 768
# 1791 1.2 1 768
# 1792 1.6 0 768
# 1793 2.0 1 768
# 1794 1.2 1 768
# 1795 1.2 1 768
# 1796 1.2 1 768
# 1797 1.2 1 768
# 1798 2.0 1 768
# 1799 1.2 1 768
# 1800 1.2 0 768
# 1801 1.2 1 768
# 1802 2.0 1 768
# 1803 1.2 1 768
# 1804 1.2 1 768
# 1805 1.2 1 768
# 1806 1.2 1 768
# 1807 2.0 1 768
# 1808 2.0 1 768
# 1809 1.2 0 768
# 1810 1.2 1 768
# 1811 2.0 1 768
# 1812 2.0 1 768
# 1813 1.2 1 768
# 1814 1.2 1 768
# 1815 2.0 0 768
# 1816 1.2 0 768
# 1817 1.2 0 768
# 1818 1.2 1 768
# 1819 1.2 0 768
# 1820 2.0 1 768
# 1821 2.0 1 768
# 1822 1.2 1 768
# 1823 2.0 0 768
# 1824 1.2 0 768
# 1825 2.0 1 768
# 1826 1.2 1 768
# 1827 1.2 0 768
# 1828 1.2 1 768
# 1829 2.0 1 768
# 1830 1.2 1 768
# 1831 2.0 1 768
# 1832 1.2 0 768
# 1833 1.2 1 768
# 1834 2.0 1 768
# 1835 2.0 0 768
# 1836 1.2 0 768
# 1837 1.2 1 768
# 1838 2.0 0 768
# 1839 1.2 1 768
# 1840 2.0 1 768
# 1841 1.2 0 768
# 1842 1.2 1 768
# 1843 1.2 1 768
# 1844 1.6 0 768
# 1845 2.0 0 768
# 1846 1.4 0 768
# 1847 1.2 1 768
# 1848 1.6 1 768
# 1849 2.0 1 768
# 1850 2.0 1 768
# 1851 1.2 0 768
# 1852 2.0 0 768
# 1853 1.6 0 768
# 1854 1.6 0 768
# 1855 1.6 0 768
# 1856 2.0 1 768
# 1857 1.6 0 768
# 1858 1.6 0 768
# 1859 2.0 0 768
# 1860 1.2 1 768
# 1861 2.0 0 768
# 1862 1.2 0 768
# 1863 1.2 1 768
# 1864 1.2 1 768
# 1865 1.2 0 768
# 1866 2.0 0 768
# 1867 2.0 0 768
# 1868 1.2 1 768
# 1869 1.2 1 768
# 1870 1.2 0 768
# 1871 1.2 1 768
# 1872 1.2 0 768
# 1873 1.2 0 768
# 1874 1.2 1 768
# 1875 2.0 0 768
# 1876 1.2 1 768
# 1877 1.2 1 768
# 1878 1.4 1 768
# 1879 2.0 1 768
# 1880 2.0 1 768
# 1881 2.0 0 768
# 1882 1.4 0 768
# 1883 1.2 0 768
# 1884 1.2 0 768
# 1885 2.0 1 768
# 1886 1.2 1 768
# 1887 2.0 0 768
# 1888 1.2 0 768
# 1889 2.0 0 768
# 1890 1.2 0 768
# 1891 2.0 0 768
# 1892 2.0 0 768
# 1893 2.0 0 768
# 1894 1.2 0 768
# 1895 1.2 1 768
# 1896 1.6 0 768
# 1897 1.6 0 768
# 1898 1.2 0 768
# 1899 1.6 0 768
# 1900 1.2 0 768
# 1901 2.0 1 768
# 1902 2.0 0 768
# 1903 2.0 1 768
# 1904 1.2 0 768
# 1905 2.0 0 768
# 1906 1.2 1 768
# 1907 1.2 1 768
# 1908 1.6 0 768
# 1909 1.2 1 768
# 1910 2.0 1 768
# 1911 2.0 1 768
# 1912 1.6 0 768
# 1913 1.2 1 768
# 1914 1.2 1 768
# 1915 1.2 1 768
# 1916 1.2 1 768
# 1917 1.2 1 768
# 1918 2.0 0 768
# 1919 1.2 1 768
# 1920 1.2 1 768
# 1921 1.2 1 768
# 1922 1.2 1 768
# 1923 2.0 1 768
# 1924 1.2 0 768
# 1925 2.0 0 768
# 1926 2.0 1 768
# 1927 1.2 1 768
# 1928 1.2 1 768
# 1929 1.2 1 768
# 1930 1.2 1 768
# 1931 1.6 1 768
# 1932 2.0 0 768
# 1933 1.2 1 768
# 1934 1.6 0 768
# 1935 1.2 0 768
# 1936 1.2 1 768
# 1937 2.0 0 768
# 1938 2.0 1 768
# 1939 1.2 0 768
# 1940 1.2 0 768
# 1941 2.0 1 768
# 1942 2.0 1 768
# 1943 2.0 1 768
# 1944 2.0 1 768
# 1945 1.2 1 768
# 1946 1.2 1 768
# 1947 1.2 0 768
# 1948 1.2 1 768
# 1949 1.2 1 768
# 1950 1.2 1 768
# 1951 1.2 0 768
# 1952 1.2 1 768
# 1953 2.0 0 768
# 1954 1.2 0 768
# 1955 1.6 0 768
# 1956 1.6 0 768
# 1957 1.2 1 768
# 1958 2.0 1 768
# 1959 1.2 0 768
# 1960 1.2 1 768
# 1961 1.2 1 768
# 1962 1.2 1 768
# 1963 1.2 1 768
# 1964 2.0 0 768
# 1965 1.2 1 768
# 1966 1.2 1 768
# 1967 1.2 1 768
# 1968 1.2 1 768
# 1969 2.0 0 768
# 1970 1.2 1 768
# 1971 2.0 0 768
# 1972 1.6 0 768
# 1973 2.0 0 768
# 1974 1.2 1 768
# 1975 2.0 1 768
# 1976 2.0 0 768
# 1977 1.2 1 768
# 1978 1.2 1 768
# 1979 1.2 1 768
# 1980 1.2 1 768
# 1981 1.2 0 768
# 1982 1.6 0 768
# 1983 2.0 0 768
# 1984 1.2 1 768
# 1985 1.2 1 768
# 1986 1.2 0 768
# 1987 1.2 0 768
# 1988 2.0 0 768
# 1989 1.2 1 768
# 1990 2.0 1 768
# 1991 1.2 1 768
# 1992 1.6 0 768
# 1993 1.2 0 768
# 1994 1.6 0 768
# 1995 2.0 0 768
# 1996 1.6 0 768
# 1997 1.2 1 768
# 1998 1.2 0 768
# 1999 2.0 1 768
# 2000 2.0 1 768
# 2001 1.2 1 768
# 2002 1.2 1 768
# 2003 1.2 0 768
# 2004 1.4 1 768
# 2005 1.2 1 768
# 2006 1.2 1 768
# 2007 1.2 1 768
# 2008 1.2 1 768
# 2009 1.6 1 768
# 2010 2.0 0 768
# 2011 2.0 0 768
# 2012 1.2 0 768
# 2013 1.2 1 768
# 2014 2.0 1 768
# 2015 1.2 0 768
# 2016 1.2 1 768
# 2017 1.6 0 768
# 2018 1.2 1 768
# 2019 1.2 0 768
# 2020 1.2 0 768
# 2021 2.0 0 768
# 2022 1.4 0 768
# 2023 1.2 1 768
# 2024 2.0 1 768
# 2025 1.2 1 768
# 2026 1.2 1 768
# 2027 1.2 0 768
# 2028 1.2 1 768
# 2029 2.0 1 768
# 2030 1.6 1 768
# 2031 1.2 0 768
# 2032 1.2 1 768
# 2033 1.2 1 768
# 2034 1.2 1 768
# 2035 1.2 0 768
# 2036 1.2 1 768
# 2037 1.2 1 768
# 2038 1.2 1 768
# 2039 1.2 1 768
# 2040 1.2 0 768
# 2041 1.2 0 768
# 2042 1.2 0 768
# 2043 2.0 0 768
# 2044 1.2 1 768
# 2045 1.2 0 768
# 2046 1.4 0 768
# 2047 2.0 1 768
# 2048 1.4 1 768
# 2049 1.2 1 768
# 2050 2.0 0 768
# 2051 1.2 0 768
# 2052 2.0 0 768
# 2053 1.2 0 768
# 2054 1.2 1 768
# 2055 1.2 1 768
# 2056 2.0 1 768
# 2057 1.0 1 768
# 2058 2.0 0 768
# 2059 1.2 0 768
# 2060 1.6 1 768
# 2061 1.6 0 768
# 2062 1.2 0 768
# 2063 1.2 0 768
# 2064 1.6 0 768
# 2065 1.2 1 768
# 2066 1.2 0 768
# 2067 1.2 1 768
# 2068 1.2 0 768
# 2069 1.2 1 768
# 2070 1.2 1 768
# 2071 1.6 0 768
# 2072 1.6 0 768
# 2073 1.2 0 768
# 2074 1.2 1 768
# 2075 1.2 1 768
# 2076 1.2 1 768
# 2077 1.2 1 768
# 2078 1.2 1 768
# 2079 1.2 0 768
# 2080 1.2 1 768
# 2081 1.2 0 768
# 2082 1.2 0 768
# 2083 1.2 1 768
# 2084 2.0 1 768
# 2085 2.0 1 768
# 2086 1.2 1 768
# 2087 2.0 1 768
# 2088 2.0 0 768
# 2089 2.0 1 768
# 2090 2.0 1 768
# 2091 2.0 1 768
# 2092 1.2 1 768
# 2093 1.6 0 768
# 2094 1.2 1 768
# 2095 1.6 1 768
# 2096 1.2 1 768
# 2097 1.2 0 768
# 2098 1.2 1 768
# 2099 1.2 0 768
# 2100 1.2 1 768
# 2101 1.2 0 768
# 2102 1.2 0 768
# 2103 1.2 1 768
# 2104 1.6 0 768
# 2105 1.2 0 768
# 2106 1.2 0 768
# 2107 1.2 1 768
# 2108 1.4 0 768
# 2109 1.2 1 768
# 2110 2.0 0 768
# 2111 1.2 0 768
# 2112 1.2 1 768
# 2113 1.2 0 768
# 2114 1.2 1 768
# 2115 1.2 0 768
# 2116 1.2 0 768
# 2117 2.0 1 768
# 2118 2.0 1 768
# 2119 2.0 0 768
# 2120 1.2 1 768
# 2121 2.0 0 768
# 2122 2.0 0 768
# 2123 2.0 0 768
# 2124 1.2 1 768
# 2125 1.2 0 768
# 2126 2.0 0 768
# 2127 1.2 0 768
# 2128 2.0 0 768
# 2129 1.2 1 768
# 2130 1.2 0 768
# 2131 2.0 0 768
# 2132 1.2 1 768
# 2133 1.4 1 768
# 2134 1.2 1 768
# 2135 1.2 0 768
# 2136 1.2 0 768
# 2137 1.2 1 768
# 2138 1.2 1 768
# 2139 1.2 0 768
# 2140 1.2 1 768
# 2141 1.2 1 768
# 2142 1.2 0 768
# 2143 2.0 1 768
# 2144 2.0 0 768
# 2145 2.0 1 768
# 2146 2.0 0 768
# 2147 1.6 0 768
# 2148 2.0 0 768
# 2149 2.0 1 768
# 2150 1.2 1 768
# 2151 1.2 1 768
# 2152 1.2 1 768
# 2153 1.6 0 768
# 2154 1.2 1 768
# 2155 2.0 1 768
# 2156 2.0 1 768
# 2157 1.2 0 768
# 2158 1.2 1 768
# 2159 1.2 1 768
# 2160 1.2 1 768
# 2161 2.0 1 768
# 2162 1.2 1 768
# 2163 1.2 1 768
# 2164 2.0 1 768
# 2165 1.2 1 768
# 2166 1.2 1 768
# 2167 1.2 0 768
# 2168 1.2 1 768
# 2169 1.2 1 768
# 2170 1.2 1 768
# 2171 1.2 1 768
# 2172 2.0 1 768
# 2173 1.2 1 768
# 2174 1.2 0 768
# 2175 1.2 1 768
# 2176 1.2 0 768
# 2177 1.2 1 768
# 2178 2.0 1 768
# 2179 1.2 1 768
# 2180 1.2 1 768
# 2181 1.2 0 768
# 2182 1.2 0 768
# 2183 1.2 0 768
# 2184 1.2 0 768
# 2185 1.2 0 768
# 2186 1.2 0 768
# 2187 2.0 0 768
# 2188 1.2 1 768
# 2189 1.2 0 768
# 2190 1.2 1 768
# 2191 1.2 0 768
# 2192 1.6 1 768
# 2193 2.0 0 768
# 2194 1.2 1 768
# 2195 1.6 0 768
# 2196 2.0 0 768
# 2197 1.6 0 768
# 2198 1.2 1 768
# 2199 1.2 0 768
# 2200 2.0 1 768
# 2201 1.2 1 768
# 2202 1.2 0 768
# 2203 2.0 1 768
# 2204 2.0 1 768
# 2205 1.6 0 768
# 2206 2.0 0 768
# 2207 1.2 1 768
# 2208 1.6 0 768
# 2209 2.0 0 768
# 2210 1.2 1 768
# 2211 1.2 1 768
# 2212 2.0 0 768
# 2213 1.2 1 768
# 2214 1.2 1 768
# 2215 2.0 0 768
# 2216 1.2 1 768
# 2217 2.0 0 768
# 2218 2.0 0 768
# 2219 2.0 0 768
# 2220 1.2 1 768
# 2221 1.2 1 768
# 2222 1.2 1 768
# 2223 1.2 1 768
# 2224 1.2 1 768
# 2225 1.2 1 768
# 2226 2.0 1 768
# 2227 1.2 1 768
# 2228 1.2 0 768
# 2229 1.2 1 768
# 2230 2.0 0 768
# 2231 1.2 1 768
# 2232 1.2 0 768
# 2233 2.0 0 768
# 2234 2.0 0 768
# 2235 2.0 1 768
# 2236 1.6 0 768
# 2237 1.2 0 768
# 2238 1.2 1 768
# 2239 2.0 1 768
# 2240 1.2 1 768
# 2241 2.0 0 768
# 2242 1.2 1 768
# 2243 1.2 1 768
# 2244 1.2 1 768
# 2245 1.2 1 768
# 2246 1.2 0 768
# 2247 2.0 0 768
# 2248 1.2 1 768
# 2249 2.0 0 768
# 2250 1.2 1 768
# 2251 1.2 1 768
# 2252 1.2 1 768
# 2253 2.0 1 768
# 2254 1.2 1 768
# 2255 1.2 1 768
# 2256 2.0 0 768
# 2257 1.2 0 768
# 2258 1.2 1 768
# 2259 2.0 1 768
# 2260 2.0 1 768
# 2261 1.2 0 768
# 2262 1.2 1 768
# 2263 1.2 0 768
# 2264 1.2 1 768
# 2265 1.2 1 768
# 2266 1.2 1 768
# 2267 1.6 0 768
# 2268 2.0 0 768
# 2269 1.2 1 768
# 2270 1.2 1 768
# 2271 2.0 0 768
# 2272 2.0 1 768
# 2273 1.2 0 768
# 2274 1.2 1 768
# 2275 1.2 1 768
# 2276 1.2 0 768
# 2277 2.0 0 768
# 2278 2.0 0 768
# 2279 1.2 1 768
# 2280 1.6 1 768
# 2281 2.0 1 768
# 2282 2.0 0 768
# 2283 1.2 0 768
# 2284 1.2 1 768
# 2285 2.0 0 768
# 2286 1.6 0 768
# 2287 2.0 0 768
# 2288 1.2 0 768
# 2289 2.0 0 768
# 2290 2.0 1 768
# 2291 1.6 1 768
# 2292 1.2 0 768
# 2293 1.2 0 768
# 2294 1.2 0 768
# 2295 1.6 0 768
# 2296 1.2 1 768
# 2297 2.0 1 768
# 2298 1.2 1 768
# 2299 1.2 1 768
# 2300 1.2 1 768
# 2301 2.0 1 768
# 2302 2.0 1 768
# 2303 2.0 1 768
# 2304 2.0 1 768
# 2305 1.2 1 768
# 2306 1.2 1 768
# 2307 1.2 0 768
# 2308 1.2 0 768
# 2309 1.2 0 768
# 2310 1.6 0 768
# 2311 1.6 0 768
# 2312 1.2 0 768
# 2313 2.0 1 768
# 2314 1.2 1 768
# 2315 2.0 1 768
# 2316 1.2 1 768
# 2317 1.2 0 768
# 2318 1.2 0 768
# 2319 1.2 1 768
# 2320 1.2 0 768
# 2321 2.0 1 768
# 2322 1.2 1 768
# 2323 1.2 0 768
# 2324 2.0 1 768
# 2325 1.2 0 768
# 2326 1.2 1 768
# 2327 2.0 1 768
# 2328 2.0 0 768
# 2329 2.0 1 768
# 2330 1.2 0 768
# 2331 2.0 0 768
# 2332 1.2 1 768
# 2333 2.0 0 768
# 2334 2.0 1 768
# 2335 1.2 1 768
# 2336 1.2 0 768
# 2337 2.0 0 768
# 2338 1.2 0 768
# 2339 2.0 1 768
# 2340 1.2 0 768
# 2341 1.2 1 768
# 2342 1.2 1 768
# 2343 1.2 0 768
# 2344 1.4 1 768
# 2345 1.2 1 768
# 2346 1.2 1 768
# 2347 1.2 1 768
# 2348 1.2 0 768
# 2349 2.0 1 768
# 2350 1.6 0 768
# 2351 2.0 0 768
# 2352 2.0 1 768
# 2353 2.0 0 768
# 2354 2.0 0 768
# 2355 1.2 0 768
# 2356 1.2 0 768
# 2357 1.2 1 768
# 2358 1.2 0 768
# 2359 1.6 1 768
# 2360 1.2 1 768
# 2361 1.2 1 768
# 2362 1.2 0 768
# 2363 2.0 1 768
# 2364 1.2 1 768
# 2365 1.2 1 768
# 2366 1.2 0 768
# 2367 1.2 1 768
# 2368 2.0 1 768
# 2369 1.2 0 768
# 2370 1.2 1 768
# 2371 1.2 1 768
# 2372 1.2 0 768
# 2373 1.2 1 768
# 2374 1.2 1 768
# 2375 1.2 1 768
# 2376 2.0 1 768
# 2377 1.2 1 768
# 2378 1.2 0 768
# 2379 2.0 0 768
# 2380 1.2 1 768
# 2381 1.6 0 768
# 2382 1.2 0 768
# 2383 2.0 1 768
# 2384 1.2 0 768
# 2385 2.0 0 768
# 2386 1.2 0 768
# 2387 1.2 0 768
# 2388 1.4 1 768
# 2389 1.2 1 768
# 2390 1.2 1 768
# 2391 2.0 1 768
# 2392 1.2 1 768
# 2393 1.2 1 768
# 2394 2.0 1 768
# 2395 1.2 1 768
# 2396 1.2 1 768
# 2397 2.0 0 768
# 2398 1.2 1 768
# 2399 2.0 0 768
# 2400 2.0 1 768
# 2401 2.0 1 768
# 2402 1.2 1 768
# 2403 1.6 1 768
# 2404 1.2 0 768
# 2405 1.2 1 768
# 2406 2.0 0 768
# 2407 1.2 1 768
# 2408 1.6 0 768
# 2409 1.2 1 768
# 2410 2.0 0 768
# 2411 1.2 0 768
# 2412 1.2 1 768
# 2413 2.0 0 768
# 2414 1.2 1 768
# 2415 1.6 0 768
# 2416 1.2 1 768
# 2417 1.2 1 768
# 2418 1.2 1 768
# 2419 1.2 1 768
# 2420 1.2 0 768
# 2421 1.2 0 768
# 2422 1.2 1 768
# 2423 2.0 1 768
# 2424 1.2 0 768
# 2425 2.0 0 768
# 2426 1.6 0 768
# 2427 1.2 1 768
# 2428 1.2 0 768
# 2429 2.0 0 768
# 2430 2.0 1 768
# 2431 2.0 0 768
# 2432 1.2 1 768
# 2433 1.6 1 768
# 2434 1.6 0 768
# 2435 1.2 1 768
# 2436 1.2 1 768
# 2437 1.2 1 768
# 2438 2.0 1 768
# 2439 1.2 0 768
# 2440 1.2 1 768
# 2441 2.0 1 768
# 2442 1.2 1 768
# 2443 1.6 0 768
# 2444 1.2 0 768
# 2445 1.2 1 768
# 2446 2.0 0 768
# 2447 1.2 0 768
# 2448 2.0 0 768
# 2449 1.2 1 768
# 2450 1.2 1 768
# 2451 1.2 0 768
# 2452 1.6 0 768
# 2453 1.2 0 768
# 2454 2.0 0 768
# 2455 1.2 0 768
# 2456 1.2 1 768
# 2457 1.2 0 768
# 2458 1.2 1 768
# 2459 1.2 1 768
# 2460 2.0 0 768
# 2461 1.2 1 768
# 2462 1.2 1 768
# 2463 1.6 0 768
# 2464 1.2 1 768
# 2465 1.2 0 768
# 2466 2.0 1 768
# 2467 1.2 1 768
# 2468 1.2 0 768
# 2469 2.0 0 768
# 2470 1.2 1 768
# 2471 1.2 0 768
# 2472 1.2 0 768
# 2473 1.6 0 768
# 2474 1.2 1 768
# 2475 1.2 1 768
# 2476 1.2 1 768
# 2477 1.2 0 768
# 2478 1.2 1 768
# 2479 1.2 1 768
# 2480 2.0 1 768
# 2481 1.2 1 768
# 2482 1.2 1 768
# 2483 1.2 0 768
# 2484 1.2 1 768
# 2485 2.0 1 768
# 2486 1.2 1 768
# 2487 2.0 1 768
# 2488 1.2 0 768
# 2489 1.2 0 768
# 2490 1.2 1 768
# 2491 2.0 1 768
# 2492 1.2 1 768
# 2493 2.0 0 768
# 2494 1.6 0 768
# 2495 2.0 0 768
# 2496 2.0 1 768
# 2497 1.6 0 768
# 2498 1.6 0 768
# 2499 1.6 0 768
# 2500 2.0 1 768
# 2501 1.2 1 768
# 2502 1.6 0 768
# 2503 1.6 0 768
# 2504 2.0 0 768
# 2505 1.2 0 768
# 2506 1.2 1 768
# 2507 1.2 0 768
# 2508 1.6 1 768
# 2509 1.2 0 768
# 2510 1.2 1 768
# 2511 2.0 1 768
# 2512 1.2 1 768
# 2513 1.2 1 768
# 2514 1.2 1 768
# 2515 1.2 0 768
# 2516 1.2 1 768
# 2517 1.2 0 768
# 2518 1.2 1 768
# 2519 2.0 0 768
# 2520 1.2 1 768
# 2521 1.2 1 768
# 2522 1.6 0 768
# 2523 2.0 1 768
# 2524 2.0 0 768
# 2525 1.2 0 768
# 2526 1.2 1 768
# 2527 1.2 0 768
# 2528 2.0 1 768
# 2529 2.0 1 768
# 2530 2.0 1 768
# 2531 1.6 0 768
# 2532 1.4 1 768
# 2533 1.2 0 768
# 2534 1.2 0 768
# 2535 1.2 0 768
# 2536 1.6 0 768
# 2537 2.0 1 768
# 2538 1.2 1 768
# 2539 1.6 0 768
# 2540 1.2 1 768
# 2541 1.2 1 768
# 2542 2.0 1 768
# 2543 2.0 1 768
# 2544 2.0 1 768
# 2545 1.2 1 768
# 2546 1.6 0 768
# 2547 1.6 0 768
# 2548 1.2 1 768
# 2549 1.2 1 768
# 2550 1.2 0 768
# 2551 1.4 0 768
# 2552 2.0 0 768
# 2553 1.2 0 768
# 2554 2.0 0 768
# 2555 1.2 1 768
# 2556 2.0 1 768
# 2557 2.0 1 768
# 2558 1.2 0 768
# 2559 1.2 0 768
# 2560 1.2 0 768
# 2561 1.4 0 768
# 2562 2.0 1 768
# 2563 1.2 1 768
# 2564 2.0 0 768
# 2565 1.2 1 768
# 2566 1.2 1 768
# 2567 1.2 1 768
# 2568 1.2 0 768
# 2569 1.2 0 768
# 2570 2.0 1 768
# 2571 1.2 1 768
# 2572 1.2 1 768
# 2573 1.2 0 768
# 2574 1.2 0 768
# 2575 2.0 0 768
# 2576 1.2 1 768
# 2577 1.2 1 768
# 2578 2.0 0 768
# 2579 2.0 1 768
# 2580 1.2 1 768
# 2581 1.2 0 768
# 2582 1.2 0 768
# 2583 2.0 1 768
# 2584 2.0 1 768
# 2585 1.2 1 768
# 2586 2.0 0 768
# 2587 2.0 0 768
# 2588 1.6 0 768
# 2589 1.4 1 768
# 2590 1.2 1 768
# 2591 1.2 1 768
# 2592 1.6 1 768
# 2593 2.0 0 768
# 2594 2.0 0 768
# 2595 1.2 1 768
# 2596 1.2 1 768
# 2597 2.0 1 768
# 2598 1.2 0 768
# 2599 2.0 0 768
# 2600 1.2 1 768
# 2601 1.2 0 768
# 2602 1.2 0 768
# 2603 2.0 1 768
# 2604 1.6 0 768
# 2605 2.0 1 768
# 2606 1.2 1 768
# 2607 1.2 0 768
# 2608 1.2 1 768
# 2609 1.2 1 768
# 2610 1.2 1 768
# 2611 2.0 1 768
# 2612 2.0 0 768
# 2613 2.0 0 768
# 2614 1.2 0 768
# 2615 1.2 1 768
# 2616 2.0 1 768
# 2617 1.2 1 768
# 2618 1.6 0 768
# 2619 1.2 0 768
# 2620 2.0 0 768
# 2621 2.0 0 768
# 2622 2.0 0 768
# 2623 2.0 1 768
# 2624 1.6 0 768
# 2625 1.6 0 768
# 2626 2.0 0 768
# 2627 1.2 0 768
# 2628 2.0 0 768
# 2629 1.2 1 768
# 2630 1.2 0 768
# 2631 1.2 0 768
# 2632 1.4 1 768
# 2633 1.2 1 768
# 2634 1.2 0 768
# 2635 2.0 0 768
# 2636 1.6 0 768
# 2637 1.4 1 768
# 2638 2.0 1 768
# 2639 1.2 1 768
# 2640 2.0 0 768
# 2641 1.2 1 768
# 2642 1.2 1 768
# 2643 2.0 0 768
# 2644 2.0 1 768
# 2645 1.2 0 768
# 2646 1.2 0 768
# 2647 2.0 1 768
# 2648 1.2 0 768
# 2649 1.2 0 768
# 2650 1.2 1 768
# 2651 1.2 0 768
# 2652 2.0 1 768
# 2653 2.0 1 768
# 2654 1.2 0 768
# 2655 2.0 1 768
# 2656 1.2 1 768
# 2657 1.2 0 768
# 2658 1.2 0 768
# 2659 1.2 0 768
# 2660 1.2 1 768
# 2661 2.0 1 768
# 2662 2.0 1 768
# 2663 1.2 0 768
# 2664 1.4 0 768
# 2665 2.0 1 768
# 2666 1.2 0 768
# 2667 1.2 1 768
# 2668 1.2 0 768
# 2669 1.4 1 768
# 2670 1.2 1 768
# 2671 2.0 0 768
# 2672 2.0 1 768
# 2673 1.2 1 768
# 2674 2.0 0 768
# 2675 1.2 1 768
# 2676 1.2 1 768
# 2677 1.2 0 768
# 2678 1.2 1 768
# 2679 2.0 0 768
# 2680 2.0 1 768
# 2681 1.2 1 768
# 2682 1.2 1 768
# 2683 2.0 1 768
# 2684 1.2 0 768
# 2685 2.0 0 768
# 2686 1.2 1 768
# 2687 1.2 1 768
# 2688 1.2 1 768
# 2689 1.2 1 768
# 2690 1.4 0 768
# 2691 1.6 1 768
# 2692 1.2 1 768
# 2693 2.0 0 768
# 2694 1.2 1 768
# 2695 2.0 1 768
# 2696 2.0 0 768
# 2697 1.6 0 768
# 2698 1.2 1 768
# 2699 1.2 1 768
# 2700 1.6 0 768
# 2701 1.2 0 768
# 2702 2.0 0 768
# 2703 2.0 0 768
# 2704 1.2 1 768
# 2705 1.2 0 768
# 2706 1.2 1 768
# 2707 1.2 1 768
# 2708 2.0 0 768
# 2709 1.2 1 768
# 2710 1.2 0 768
# 2711 1.6 0 768
# 2712 1.2 0 768
# 2713 1.2 0 768
# 2714 1.2 0 768
# 2715 1.2 1 768
# 2716 1.2 1 768
# 2717 2.0 1 768
# 2718 2.0 1 768
# 2719 1.2 1 768
# 2720 1.2 1 768
# 2721 2.0 1 768
# 2722 1.6 0 768
# 2723 1.2 1 768
# 2724 2.0 0 768
# 2725 2.0 1 768
# 2726 2.0 0 768
# 2727 1.4 0 768
# 2728 1.2 1 768
# 2729 1.2 1 768
# 2730 2.0 1 768
# 2731 1.2 1 768
# 2732 1.2 1 768
# 2733 2.0 0 768
# 2734 1.2 1 768
# 2735 1.2 1 768
# 2736 1.2 0 768
# 2737 2.0 0 768
# 2738 2.0 0 768
# 2739 2.0 1 768
# 2740 1.2 1 768
# 2741 1.2 1 768
# 2742 2.0 0 768
# 2743 1.2 1 768
# 2744 2.0 0 768
# 2745 2.0 1 768
# 2746 2.0 1 768
# 2747 1.2 1 768
# 2748 1.6 1 768
# 2749 1.2 1 768
# 2750 1.2 0 768
# 2751 1.2 1 768
# 2752 1.2 1 768
# 2753 1.2 0 768
# 2754 2.0 1 768
# 2755 1.6 0 768
# 2756 1.2 1 768
# 2757 1.2 1 768
# 2758 1.2 1 768
# 2759 1.2 1 768
# 2760 1.2 1 768
# 2761 2.0 1 768
# 2762 2.0 0 768
# 2763 1.2 0 768
# 2764 2.0 1 768
# 2765 1.2 1 768
# 2766 1.2 0 768
# 2767 1.2 0 768
# 2768 1.2 1 768
# 2769 1.6 0 768
# 2770 2.0 0 768
# 2771 1.2 1 768
# 2772 1.2 1 768
# 2773 1.2 1 768
# 2774 1.2 0 768
# 2775 2.0 1 768
# 2776 1.2 1 768
# 2777 1.2 1 768
# 2778 1.2 0 768
# 2779 1.2 1 768
# 2780 1.2 1 768
# 2781 1.2 0 768
# 2782 1.2 1 768
# 2783 2.0 1 768
# 2784 1.2 0 768
# 2785 1.6 0 768
# 2786 2.0 0 768
# 2787 2.0 0 768
# 2788 2.0 0 768
# 2789 1.2 1 768
# 2790 2.0 0 768
# 2791 1.2 0 768
# 2792 1.2 1 768
# 2793 1.2 1 768
# 2794 1.2 0 768
# 2795 1.2 1 768
# 2796 1.2 1 768
# 2797 2.0 0 768
# 2798 2.0 1 768
# 2799 1.2 1 768
# 2800 1.2 0 768
# 2801 1.6 0 768
# 2802 2.0 1 768
# 2803 2.0 0 768
# 2804 1.2 1 768
# 2805 1.2 0 768
# 2806 1.6 0 768
# 2807 2.0 1 768
# 2808 2.0 0 768
# 2809 1.2 0 768
# 2810 1.2 0 768
# 2811 1.2 0 768
# 2812 2.0 0 768
# 2813 1.2 1 768
# 2814 1.6 0 768
# 2815 1.2 1 768
# 2816 1.2 1 768
# 2817 2.0 0 768
# 2818 1.6 0 768
# 2819 2.0 0 768
# 2820 1.2 0 768
# 2821 1.4 1 768
# 2822 2.0 0 768
# 2823 1.6 0 768
# 2824 1.2 1 768
# 2825 1.2 1 768
# 2826 2.0 0 768
# 2827 1.2 0 768
# 2828 1.2 1 768
# 2829 1.2 1 768
# 2830 2.0 0 768
# 2831 1.2 0 768
# 2832 1.2 0 768
# 2833 1.2 1 768
# 2834 2.0 1 768
# 2835 2.0 0 768
# 2836 1.2 0 768
# 2837 1.2 1 768
# 2838 2.0 0 768
# 2839 2.0 0 768
# 2840 1.2 1 768
# 2841 1.2 1 768
# 2842 1.2 1 768
# 2843 1.2 1 768
# 2844 1.2 0 768
# 2845 2.0 1 768
# 2846 1.4 0 768
# 2847 1.6 0 768
# 2848 1.2 1 768
# 2849 1.2 0 768
# 2850 2.0 0 768
# 2851 1.2 1 768
# 2852 2.0 1 768
# 2853 1.2 0 768
# 2854 2.0 0 768
# 2855 1.2 1 768
# 2856 1.6 1 768
# 2857 1.2 0 768
# 2858 1.2 0 768
# 2859 1.6 0 768
# 2860 2.0 0 768
# 2861 1.6 0 768
# 2862 2.0 1 768
# 2863 2.0 0 768
# 2864 1.2 0 768
# 2865 1.0 1 768
# 2866 1.6 0 768
# 2867 1.2 0 768
# 2868 1.2 1 768
# 2869 2.0 0 768
# 2870 1.2 0 768
# 2871 1.2 0 768
# 2872 1.2 1 768
# 2873 2.0 0 768
# 2874 1.2 1 768
# 2875 1.2 1 768
# 2876 1.2 1 768
# 2877 1.2 0 768
# 2878 1.2 1 768
# 2879 2.0 1 768
# 2880 2.0 0 768
# 2881 1.2 1 768
# 2882 1.2 0 768
# 2883 1.6 0 768
# 2884 2.0 1 768
# 2885 1.2 0 768
# 2886 1.6 0 768
# 2887 1.2 1 768
# 2888 1.2 0 768
# 2889 1.2 1 768
# 2890 1.2 0 768
# 2891 1.6 0 768
# 2892 1.2 0 768
# 2893 2.0 1 768
# 2894 1.2 0 768
# 2895 2.0 0 768
# 2896 2.0 1 768
# 2897 1.2 1 768
# 2898 2.0 0 768
# 2899 1.2 0 768
# 2900 1.6 0 768
# 2901 1.2 1 768
# 2902 1.2 1 768
# 2903 1.2 1 768
# 2904 1.2 1 768
# 2905 2.0 1 768
# 2906 1.2 0 768
# 2907 1.6 0 768
# 2908 1.2 0 768
# 2909 1.6 0 768
# 2910 2.0 0 768
# 2911 1.2 1 768
# 2912 2.0 1 768
# 2913 2.0 1 768
# 2914 1.2 1 768
# 2915 1.2 1 768
# 2916 1.2 1 768
# 2917 2.0 1 768
# 2918 1.2 1 768
# 2919 2.0 0 768
# 2920 1.6 0 768
# 2921 1.2 1 768
# 2922 2.0 0 768
# 2923 1.2 1 768
# 2924 2.0 0 768
# 2925 1.2 0 768
# 2926 1.2 1 768
# 2927 1.2 0 768
# 2928 1.2 1 768
# 2929 1.2 1 768
# 2930 1.2 0 768
# 2931 2.0 0 768
# 2932 1.2 0 768
# 2933 1.6 0 768
# 2934 1.4 0 768
# 2935 1.2 0 768
# 2936 1.2 0 768
# 2937 1.2 1 768
# 2938 1.6 0 768
# 2939 2.0 1 768
# 2940 1.6 0 768
# 2941 1.0 1 768
# 2942 1.2 0 768
# 2943 1.2 1 768
# 2944 1.2 1 768
# 2945 1.6 0 768
# 2946 2.0 1 768
# 2947 2.0 1 768
# 2948 1.2 0 768
# 2949 1.2 0 768
# 2950 1.2 1 768
# 2951 1.2 1 768
# 2952 1.2 0 768
# 2953 2.0 0 768
# 2954 1.2 0 768
# 2955 1.2 1 768
# 2956 1.2 1 768
# 2957 1.2 0 768
# 2958 2.0 1 768
# 2959 1.2 1 768
# 2960 1.2 1 768
# 2961 1.2 1 768
# 2962 1.2 1 768
# 2963 1.2 1 768
# 2964 1.4 1 768
# 2965 2.0 1 768
# 2966 1.2 1 768
# 2967 1.2 0 768
# 2968 1.2 1 768
# 2969 1.2 1 768
# 2970 1.6 0 768
# 2971 2.0 1 768
# 2972 1.2 1 768
# 2973 2.0 1 768
# 2974 2.0 0 768
# 2975 1.4 1 768
# 2976 1.2 1 768
# 2977 1.2 1 768
# 2978 1.6 0 768
# 2979 1.6 1 768
# 2980 2.0 1 768
# 2981 1.2 0 768
# 2982 1.2 0 768
# 2983 1.2 1 768
# 2984 1.2 1 768
# 2985 1.2 1 768
# 2986 2.0 1 768
# 2987 1.6 0 768
# 2988 2.0 1 768
# 2989 1.2 1 768
# 2990 1.2 1 768
# 2991 1.2 0 768
# 2992 1.2 1 768
# 2993 1.2 0 768
# 2994 2.0 1 768
# 2995 2.0 0 768
# 2996 1.2 0 768
# 2997 1.2 1 768
# 2998 1.2 0 768
# 2999 2.0 1 768
# 3000 1.2 1 768
# 3001 2.0 1 768
# 3002 2.0 1 768
# 3003 1.2 1 768
# 3004 2.0 1 768
# 3005 1.2 1 768
# 3006 2.0 0 768
# 3007 1.2 0 768
# 3008 2.0 0 768
# 3009 1.2 0 768
# 3010 2.0 1 768
# 3011 1.2 0 768
# 3012 1.0 1 768
# 3013 1.2 0 768
# 3014 1.2 0 768
# 3015 1.2 1 768
# 3016 1.2 1 768
# 3017 1.2 1 768
# 3018 1.4 0 768
# 3019 1.2 1 768
# 3020 1.2 1 768
# 3021 1.6 0 768
# 3022 2.0 0 768
# 3023 1.2 0 768
# 3024 1.6 1 768
# 3025 1.2 1 768
# 3026 1.2 1 768
# 3027 1.2 1 768
# 3028 2.0 0 768
# 3029 2.0 0 768
# 3030 1.4 0 768
# 3031 1.2 0 768
# 3032 2.0 0 768
# 3033 1.2 1 768
# 3034 2.0 0 768
# 3035 2.0 1 768
# 3036 2.0 0 768
# 3037 2.0 1 768
# 3038 2.0 0 768
# 3039 1.6 0 768
# 3040 1.2 0 768
# 3041 1.2 1 768
# 3042 2.0 0 768
# 3043 1.2 1 768
# 3044 1.2 0 768
# 3045 2.0 1 768
# 3046 1.2 1 768
# 3047 2.0 0 768
# 3048 2.0 0 768
# 3049 2.0 1 768
# 3050 1.2 0 768
# 3051 2.0 0 768
# 3052 2.0 0 768
# 3053 1.2 0 768
# 3054 2.0 1 768
# 3055 1.2 1 768
# 3056 2.0 1 768
# 3057 1.2 0 768
# 3058 2.0 1 768
# 3059 1.2 0 768
# 3060 1.2 1 768
# 3061 1.2 1 768
# 3062 2.0 0 768
# 3063 1.2 1 768
# 3064 1.2 1 768
# 3065 1.2 1 768
# 3066 1.2 1 768
# 3067 2.0 1 768
# 3068 2.0 0 768
# 3069 1.6 0 768
# 3070 1.2 1 768
# 3071 1.2 0 768
# 3072 1.2 0 768
# 3073 1.2 1 768
# 3074 1.2 1 768
# 3075 1.2 1 768
# 3076 2.0 1 768
# 3077 2.0 1 768
# 3078 1.6 0 768
# 3079 1.6 0 768
# 3080 1.2 1 768
# 3081 1.6 0 768
# 3082 2.0 1 768
# 3083 2.0 1 768
# 3084 1.6 0 768
# 3085 1.6 1 768
# 3086 1.2 0 768
# 3087 1.2 0 768
# 3088 1.6 0 768
# 3089 1.2 1 768
# 3090 1.2 1 768
# 3091 1.6 0 768
# 3092 1.2 1 768
# 3093 1.2 0 768
# 3094 2.0 1 768
# 3095 1.4 0 768
# 3096 2.0 1 768
# 3097 1.2 1 768
# 3098 1.2 0 768
# 3099 1.2 1 768
# 3100 1.2 1 768
# 3101 2.0 0 768
# 3102 1.2 0 768
# 3103 1.2 1 768
# 3104 1.2 0 768
# 3105 2.0 0 768
# 3106 2.0 0 768
# 3107 1.2 1 768
# 3108 1.2 1 768
# 3109 1.2 1 768
# 3110 2.0 1 768
# 3111 1.2 1 768
# 3112 1.2 1 768
# 3113 1.2 0 768
# 3114 1.2 1 768
# 3115 1.2 1 768
# 3116 2.0 0 768
# 3117 1.2 0 768
# 3118 1.2 0 768
# 3119 1.2 1 768
# 3120 2.0 1 768
# 3121 1.4 1 768
# 3122 1.6 1 768
# 3123 1.2 0 768
# 3124 1.2 1 768
# 3125 1.2 1 768
# 3126 1.2 1 768
# 3127 2.0 0 768
# 3128 1.2 0 768
# 3129 1.2 1 768
# 3130 1.2 1 768
# 3131 1.6 0 768
# 3132 2.0 1 768
# 3133 2.0 0 768
# 3134 1.2 1 768
# 3135 1.2 1 768
# 3136 1.2 0 768
# 3137 1.2 1 768
# 3138 2.0 0 768
# 3139 1.2 1 768
# 3140 1.6 0 768
# 3141 1.2 0 768
# 3142 1.2 0 768
# 3143 1.2 1 768
# 3144 1.2 0 768
# 3145 1.2 1 768
# 3146 2.0 1 768
# 3147 2.0 1 768
# 3148 2.0 1 768
# 3149 1.2 0 768
# 3150 2.0 0 768
# 3151 1.2 1 768
# 3152 1.2 1 768
# 3153 1.2 1 768
# 3154 1.2 1 768
# 3155 1.2 1 768
# 3156 2.0 1 768
# 3157 1.2 1 768
# 3158 2.0 1 768
# 3159 1.2 1 768
# 3160 1.2 1 768
# 3161 1.2 1 768
# 3162 2.0 1 768
# 3163 2.0 0 768
# 3164 1.2 1 768
# 3165 1.4 1 768
# 3166 1.2 1 768
# 3167 2.0 1 768
# 3168 1.6 0 768
# 3169 1.4 0 768
# 3170 2.0 0 768
# 3171 1.2 1 768
# 3172 1.2 1 768
# 3173 2.0 0 768
# 3174 1.2 1 768
# 3175 1.6 0 768
# 3176 2.0 1 768
# 3177 1.2 1 768
# 3178 1.2 1 768
# 3179 1.2 0 768
# 3180 2.0 1 768
# 3181 1.2 0 768
# 3182 1.2 1 768
# 3183 1.2 0 768
# 3184 2.0 1 768
# 3185 1.2 1 768
# 3186 1.2 1 768
# 3187 2.0 0 768
# 3188 1.2 0 768
# 3189 1.6 0 768
# 3190 1.2 1 768
# 3191 1.2 0 768
# 3192 1.2 0 768
# 3193 1.4 0 768
# 3194 2.0 0 768
# 3195 1.2 1 768
# 3196 2.0 0 768
# 3197 2.0 1 768
# 3198 2.0 1 768
# 3199 1.6 0 768
# 3200 1.2 0 768
# 3201 1.6 0 768
# 3202 1.2 1 768
# 3203 1.4 1 768
# 3204 1.2 0 768
# 3205 2.0 1 768
# 3206 2.0 1 768
# 3207 2.0 0 768
# 3208 1.2 1 768
# 3209 1.2 1 768
# 3210 2.0 1 768
# 3211 1.2 0 768
# 3212 2.0 1 768
# 3213 1.0 1 768
# 3214 1.2 1 768
# 3215 2.0 1 768
# 3216 1.4 0 768
# 3217 1.2 1 768
# 3218 1.2 0 768
# 3219 2.0 1 768
# 3220 1.2 1 768
# 3221 2.0 0 768
# 3222 2.0 0 768
# 3223 1.2 1 768
# 3224 1.2 0 768
# 3225 1.4 1 768
# 3226 2.0 1 768
# 3227 1.2 0 768
# 3228 1.2 1 768
# 3229 2.0 1 768
# 3230 1.2 1 768
# 3231 1.2 1 768
# 3232 1.6 1 768
# 3233 2.0 1 768
# 3234 1.6 0 768
# 3235 1.2 1 768
# 3236 2.0 0 768
# 3237 1.2 0 768
# 3238 2.0 0 768
# 3239 1.2 0 768
# 3240 2.0 1 768
# 3241 1.2 1 768
# 3242 1.2 0 768
# 3243 2.0 1 768
# 3244 1.6 0 768
# 3245 2.0 1 768
# 3246 1.2 1 768
# 3247 1.2 0 768
# 3248 1.6 0 768
# 3249 1.6 0 768
# 3250 2.0 0 768
# 3251 1.6 0 768
# 3252 2.0 1 768
# 3253 1.2 0 768
# 3254 2.0 0 768
# 3255 2.0 0 768
# 3256 1.6 1 768
# 3257 1.2 1 768
# 3258 1.2 0 768
# 3259 1.2 0 768
# 3260 2.0 1 768
# 3261 1.2 0 768
# 3262 2.0 0 768
# 3263 1.2 0 768
# 3264 2.0 0 768
# 3265 1.6 0 768
# 3266 1.2 1 768
# 3267 1.2 1 768
# 3268 1.2 1 768
# 3269 2.0 1 768
# 3270 1.2 0 768
# 3271 1.6 0 768
# 3272 2.0 0 768
# 3273 2.0 0 768
# ...
# 123812 1.2 0 768
# 123813 2.0 0 768
# 123814 1.2 1 768
# 123815 1.2 1 768
# 123816 2.0 0 768
# 123817 2.0 0 768
# 123818 2.0 0 768
# 123819 1.2 0 768
# 123820 1.2 1 768
# 123821 1.2 1 768
# 123822 1.2 0 768
# 123823 1.2 1 768
# 123824 1.2 0 768
# 123825 1.2 1 768
# 123826 2.0 1 768
# 123827 1.2 1 768
# 123828 1.2 0 768
# 123829 1.2 0 768
# 123830 2.0 0 768
# 123831 1.2 1 768
# 123832 2.0 0 768
# 123833 2.0 1 768
# 123834 1.6 0 768
# 123835 1.2 1 768
# 123836 1.2 0 768
# 123837 2.0 0 768
# 123838 1.2 1 768
# 123839 1.2 0 768
# 123840 1.4 1 768
# 123841 2.0 1 768
# 123842 1.2 1 768
# 123843 1.2 0 768
# 123844 2.0 0 768
# 123845 1.6 0 768
# 123846 1.2 1 768
# 123847 1.2 0 768
# 123848 1.2 1 768
# 123849 2.0 1 768
# 123850 1.2 0 768
# 123851 2.0 1 768
# 123852 1.2 1 768
# 123853 1.2 0 768
# 123854 1.4 0 768
# 123855 1.2 1 768
# 123856 1.2 1 768
# 123857 1.6 0 768
# 123858 1.6 0 768
# 123859 2.0 1 768
# 123860 1.2 0 768
# 123861 1.2 1 768
# 123862 1.6 0 768
# 123863 1.2 1 768
# 123864 1.2 1 768
# 123865 2.0 1 768
# 123866 1.6 0 768
# 123867 1.2 1 768
# 123868 1.6 0 768
# 123869 1.6 1 768
# 123870 1.2 1 768
# 123871 1.2 0 768
# 123872 2.0 0 768
# 123873 1.2 1 768
# 123874 1.2 1 768
# 123875 2.0 1 768
# 123876 1.2 1 768
# 123877 1.2 0 768
# 123878 1.2 0 768
# 123879 1.2 0 768
# 123880 2.0 1 768
# 123881 1.2 1 768
# 123882 2.0 0 768
# 123883 2.0 1 768
# 123884 1.2 0 768
# 123885 1.2 0 768
# 123886 1.2 1 768
# 123887 2.0 0 768
# 123888 1.2 0 768
# 123889 2.0 1 768
# 123890 2.0 0 768
# 123891 2.0 0 768
# 123892 1.2 1 768
# 123893 1.6 0 768
# 123894 1.2 0 768
# 123895 2.0 0 768
# 123896 1.2 1 768
# 123897 1.2 1 768
# 123898 1.2 1 768
# 123899 2.0 1 768
# 123900 1.6 0 768
# 123901 1.6 0 768
# 123902 1.2 1 768
# 123903 2.0 0 768
# 123904 1.2 1 768
# 123905 1.2 1 768
# 123906 2.0 0 768
# 123907 1.2 1 768
# 123908 1.2 0 768
# 123909 1.4 0 768
# 123910 1.2 0 768
# 123911 1.6 0 768
# 123912 1.2 1 768
# 123913 2.0 0 768
# 123914 2.0 0 768
# 123915 2.0 1 768
# 123916 1.2 1 768
# 123917 1.2 0 768
# 123918 1.2 1 768
# 123919 2.0 0 768
# 123920 2.0 0 768
# 123921 1.2 1 768
# 123922 1.6 1 768
# 123923 1.6 0 768
# 123924 2.0 1 768
# 123925 1.2 1 768
# 123926 1.2 0 768
# 123927 2.0 1 768
# 123928 1.2 1 768
# 123929 2.0 1 768
# 123930 1.6 0 768
# 123931 2.0 0 768
# 123932 1.2 1 768
# 123933 1.2 1 768
# 123934 2.0 1 768
# 123935 2.0 1 768
# 123936 1.2 0 768
# 123937 1.2 1 768
# 123938 2.0 0 768
# 123939 1.2 1 768
# 123940 2.0 0 768
# 123941 1.2 0 768
# 123942 1.2 0 768
# 123943 1.6 0 768
# 123944 1.2 0 768
# 123945 1.2 0 768
# 123946 1.2 1 768
# 123947 1.2 1 768
# 123948 1.2 1 768
# 123949 1.2 1 768
# 123950 2.0 1 768
# 123951 1.6 0 768
# 123952 1.2 1 768
# 123953 1.2 1 768
# 123954 2.0 1 768
# 123955 1.2 0 768
# 123956 2.0 1 768
# 123957 2.0 0 768
# 123958 2.0 1 768
# 123959 1.6 0 768
# 123960 1.2 0 768
# 123961 2.0 0 768
# 123962 2.0 0 768
# 123963 1.2 0 768
# 123964 1.2 1 768
# 123965 1.2 0 768
# 123966 1.2 1 768
# 123967 1.2 0 768
# 123968 2.0 0 768
# 123969 1.2 1 768
# 123970 1.2 1 768
# 123971 1.2 1 768
# 123972 1.2 0 768
# 123973 1.2 0 768
# 123974 1.2 1 768
# 123975 1.2 0 768
# 123976 1.2 1 768
# 123977 1.2 1 768
# 123978 2.0 0 768
# 123979 1.2 0 768
# 123980 1.2 0 768
# 123981 1.2 0 768
# 123982 1.2 1 768
# 123983 2.0 0 768
# 123984 1.2 1 768
# 123985 1.2 1 768
# 123986 1.2 0 768
# 123987 2.0 0 768
# 123988 1.6 0 768
# 123989 1.2 1 768
# 123990 1.2 1 768
# 123991 1.6 0 768
# 123992 1.2 0 768
# 123993 1.2 1 768
# 123994 2.0 1 768
# 123995 1.2 1 768
# 123996 1.2 1 768
# 123997 1.2 0 768
# 123998 2.0 0 768
# 123999 1.2 1 768
# 124000 1.6 0 768
# 124001 1.2 1 768
# 124002 1.2 1 768
# 124003 2.0 0 768
# 124004 2.0 1 768
# 124005 1.2 1 768
# 124006 2.0 1 768
# 124007 1.2 1 768
# 124008 1.6 0 768
# 124009 1.2 0 768
# 124010 2.0 1 768
# 124011 1.2 1 768
# 124012 2.0 0 768
# 124013 1.6 0 768
# 124014 2.0 0 768
# 124015 1.2 0 768
# 124016 2.0 1 768
# 124017 1.2 1 768
# 124018 1.2 0 768
# 124019 2.0 1 768
# 124020 2.0 0 768
# 124021 1.2 0 768
# 124022 1.6 0 768
# 124023 1.2 1 768
# 124024 1.2 1 768
# 124025 2.0 0 768
# 124026 1.2 1 768
# 124027 1.6 0 768
# 124028 1.2 0 768
# 124029 1.2 1 768
# 124030 1.6 0 768
# 124031 2.0 1 768
# 124032 2.0 0 768
# 124033 1.2 0 768
# 124034 2.0 1 768
# 124035 1.2 0 768
# 124036 1.2 1 768
# 124037 1.2 0 768
# 124038 1.2 0 768
# 124039 1.6 0 768
# 124040 1.2 1 768
# 124041 1.6 0 768
# 124042 1.2 0 768
# 124043 1.2 1 768
# 124044 1.2 0 768
# 124045 1.4 1 768
# 124046 1.2 0 768
# 124047 2.0 1 768
# 124048 1.2 1 768
# 124049 2.0 1 768
# 124050 2.0 1 768
# 124051 2.0 0 768
# 124052 2.0 0 768
# 124053 1.2 0 768
# 124054 1.2 1 768
# 124055 1.2 1 768
# 124056 1.2 0 768
# 124057 1.6 0 768
# 124058 2.0 1 768
# 124059 2.0 0 768
# 124060 1.2 1 768
# 124061 1.2 1 768
# 124062 2.0 0 768
# 124063 2.0 1 768
# 124064 1.6 0 768
# 124065 1.2 1 768
# 124066 2.0 1 768
# 124067 1.2 0 768
# 124068 2.0 0 768
# 124069 1.2 0 768
# 124070 1.2 1 768
# 124071 1.2 0 768
# 124072 2.0 0 768
# 124073 1.2 0 768
# 124074 2.0 0 768
# 124075 2.0 1 768
# 124076 1.2 0 768
# 124077 2.0 0 768
# 124078 2.0 1 768
# 124079 1.6 0 768
# 124080 1.2 0 768
# 124081 1.2 0 768
# 124082 2.0 1 768
# 124083 1.6 1 768
# 124084 1.2 1 768
# 124085 2.0 0 768
# 124086 2.0 0 768
# 124087 1.2 0 768
# 124088 2.0 0 768
# 124089 1.2 0 768
# 124090 1.2 1 768
# 124091 2.0 0 768
# 124092 1.2 0 768
# 124093 2.0 1 768
# 124094 1.2 0 768
# 124095 1.2 1 768
# 124096 2.0 1 768
# 124097 1.2 0 768
# 124098 1.2 1 768
# 124099 1.2 0 768
# 124100 1.2 1 768
# 124101 1.2 1 768
# 124102 1.2 1 768
# 124103 1.2 0 768
# 124104 2.0 0 768
# 124105 1.2 1 768
# 124106 1.2 0 768
# 124107 1.4 1 768
# 124108 1.2 1 768
# 124109 1.2 0 768
# 124110 2.0 1 768
# 124111 1.2 0 768
# 124112 2.0 1 768
# 124113 2.0 1 768
# 124114 1.2 1 768
# 124115 1.6 0 768
# 124116 2.0 1 768
# 124117 1.2 1 768
# 124118 1.2 1 768
# 124119 2.0 1 768
# 124120 2.0 0 768
# 124121 2.0 1 768
# 124122 1.2 1 768
# 124123 1.6 0 768
# 124124 1.2 1 768
# 124125 1.2 0 768
# 124126 2.0 0 768
# 124127 1.2 1 768
# 124128 1.2 0 768
# 124129 1.2 1 768
# 124130 2.0 0 768
# 124131 1.2 0 768
# 124132 2.0 1 768
# 124133 1.6 0 768
# 124134 1.2 0 768
# 124135 2.0 1 768
# 124136 1.2 0 768
# 124137 1.2 1 768
# 124138 1.2 1 768
# 124139 1.6 0 768
# 124140 1.2 1 768
# 124141 2.0 1 768
# 124142 2.0 0 768
# 124143 1.2 0 768
# 124144 2.0 0 768
# 124145 1.2 0 768
# 124146 2.0 1 768
# 124147 1.2 0 768
# 124148 1.6 0 768
# 124149 1.4 1 768
# 124150 2.0 0 768
# 124151 1.2 1 768
# 124152 1.2 1 768
# 124153 1.2 1 768
# 124154 1.2 1 768
# 124155 1.2 0 768
# 124156 2.0 1 768
# 124157 1.2 1 768
# 124158 1.2 1 768
# 124159 1.2 1 768
# 124160 1.2 1 768
# 124161 1.2 1 768
# 124162 1.6 0 768
# 124163 1.6 1 768
# 124164 1.2 1 768
# 124165 1.6 0 768
# 124166 2.0 0 768
# 124167 1.2 1 768
# 124168 1.2 0 768
# 124169 1.2 1 768
# 124170 2.0 0 768
# 124171 1.2 1 768
# 124172 1.2 1 768
# 124173 1.6 0 768
# 124174 1.2 0 768
# 124175 1.2 0 768
# 124176 1.6 0 768
# 124177 1.2 1 768
# 124178 1.2 0 768
# 124179 1.2 1 768
# 124180 1.2 1 768
# 124181 2.0 0 768
# 124182 1.2 0 768
# 124183 2.0 1 768
# 124184 2.0 0 768
# 124185 1.6 0 768
# 124186 2.0 1 768
# 124187 2.0 0 768
# 124188 1.2 1 768
# 124189 1.2 0 768
# 124190 1.6 1 768
# 124191 1.2 1 768
# 124192 1.2 1 768
# 124193 1.2 0 768
# 124194 2.0 1 768
# 124195 1.2 0 768
# 124196 1.2 1 768
# 124197 2.0 0 768
# 124198 2.0 0 768
# 124199 2.0 1 768
# 124200 2.0 1 768
# 124201 1.2 1 768
# 124202 1.2 1 768
# 124203 1.2 1 768
# 124204 2.0 1 768
# 124205 2.0 0 768
# 124206 1.2 1 768
# 124207 1.6 0 768
# 124208 2.0 0 768
# 124209 1.2 1 768
# 124210 1.2 0 768
# 124211 1.2 1 768
# 124212 2.0 0 768
# 124213 1.2 1 768
# 124214 2.0 1 768
# 124215 2.0 0 768
# 124216 1.2 1 768
# 124217 1.2 1 768
# 124218 1.2 1 768
# 124219 2.0 0 768
# 124220 2.0 0 768
# 124221 2.0 1 768
# 124222 2.0 1 768
# 124223 1.2 0 768
# 124224 1.2 0 768
# 124225 1.2 1 768
# 124226 1.2 1 768
# 124227 1.6 0 768
# 124228 1.4 1 768
# 124229 2.0 0 768
# 124230 1.2 0 768
# 124231 1.2 0 768
# 124232 2.0 1 768
# 124233 2.0 0 768
# 124234 1.2 0 768
# 124235 1.2 1 768
# 124236 1.2 1 768
# 124237 2.0 1 768
# 124238 2.0 0 768
# 124239 2.0 1 768
# 124240 1.2 0 768
# 124241 2.0 1 768
# 124242 2.0 0 768
# 124243 1.2 1 768
# 124244 1.6 0 768
# 124245 1.0 1 768
# 124246 1.2 1 768
# 124247 1.2 0 768
# 124248 1.2 1 768
# 124249 1.2 0 768
# 124250 1.2 1 768
# 124251 1.2 1 768
# 124252 1.2 1 768
# 124253 2.0 0 768
# 124254 1.2 0 768
# 124255 1.2 1 768
# 124256 2.0 1 768
# 124257 1.2 0 768
# 124258 1.2 0 768
# 124259 2.0 1 768
# 124260 1.2 0 768
# 124261 1.2 0 768
# 124262 1.2 1 768
# 124263 1.2 1 768
# 124264 1.2 0 768
# 124265 1.2 0 768
# 124266 1.2 1 768
# 124267 1.2 0 768
# 124268 1.2 0 768
# 124269 1.6 0 768
# 124270 1.2 0 768
# 124271 1.2 1 768
# 124272 2.0 0 768
# 124273 1.6 1 768
# 124274 1.2 0 768
# 124275 1.2 0 768
# 124276 1.2 1 768
# 124277 1.2 1 768
# 124278 1.2 1 768
# 124279 1.2 1 768
# 124280 1.2 0 768
# 124281 2.0 1 768
# 124282 1.2 1 768
# 124283 1.2 1 768
# 124284 2.0 1 768
# 124285 1.0 1 768
# 124286 2.0 1 768
# 124287 1.2 1 768
# 124288 2.0 0 768
# 124289 2.0 0 768
# 124290 1.2 1 768
# 124291 1.2 0 768
# 124292 1.6 1 768
# 124293 2.0 1 768
# 124294 1.2 0 768
# 124295 1.2 1 768
# 124296 1.2 1 768
# 124297 2.0 0 768
# 124298 1.2 0 768
# 124299 1.6 0 768
# 124300 2.0 0 768
# 124301 1.2 1 768
# 124302 1.4 1 768
# 124303 1.2 1 768
# 124304 1.2 1 768
# 124305 1.6 0 768
# 124306 1.6 0 768
# 124307 1.2 1 768
# 124308 2.0 1 768
# 124309 1.2 1 768
# 124310 1.2 0 768
# 124311 2.0 1 768
# 124312 2.0 0 768
# 124313 1.2 1 768
# 124314 1.2 1 768
# 124315 1.6 0 768
# 124316 1.6 1 768
# 124317 1.2 1 768
# 124318 1.2 0 768
# 124319 1.2 0 768
# 124320 1.2 0 768
# 124321 2.0 1 768
# 124322 1.2 1 768
# 124323 1.2 1 768
# 124324 1.6 1 768
# 124325 1.6 0 768
# 124326 2.0 0 768
# 124327 2.0 0 768
# 124328 2.0 1 768
# 124329 1.6 0 768
# 124330 1.2 1 768
# 124331 2.0 1 768
# 124332 1.2 1 768
# 124333 1.2 0 768
# 124334 2.0 0 768
# 124335 2.0 1 768
# 124336 1.2 1 768
# 124337 1.2 0 768
# 124338 1.2 1 768
# 124339 1.2 0 768
# 124340 1.6 0 768
# 124341 1.2 1 768
# 124342 1.2 1 768
# 124343 2.0 1 768
# 124344 1.4 1 768
# 124345 1.2 1 768
# 124346 2.0 1 768
# 124347 1.2 1 768
# 124348 2.0 1 768
# 124349 2.0 0 768
# 124350 1.2 1 768
# 124351 1.2 0 768
# 124352 2.0 0 768
# 124353 1.2 0 768
# 124354 1.2 1 768
# 124355 1.2 0 768
# 124356 1.2 1 768
# 124357 1.2 1 768
# 124358 1.2 0 768
# 124359 1.2 0 768
# 124360 2.0 0 768
# 124361 1.2 1 768
# 124362 1.6 0 768
# 124363 1.6 0 768
# 124364 2.0 0 768
# 124365 1.2 1 768
# 124366 1.2 1 768
# 124367 2.0 1 768
# 124368 2.0 1 768
# 124369 2.0 1 768
# 124370 1.2 1 768
# 124371 2.0 1 768
# 124372 2.0 1 768
# 124373 1.6 0 768
# 124374 1.2 1 768
# 124375 2.0 1 768
# 124376 1.6 0 768
# 124377 2.0 0 768
# 124378 1.2 0 768
# 124379 1.2 1 768
# 124380 2.0 1 768
# 124381 2.0 0 768
# 124382 1.2 1 768
# 124383 1.2 1 768
# 124384 1.2 1 768
# 124385 2.0 0 768
# 124386 1.2 1 768
# 124387 2.0 1 768
# 124388 1.6 0 768
# 124389 2.0 1 768
# 124390 1.2 1 768
# 124391 2.0 1 768
# 124392 1.2 1 768
# 124393 2.0 0 768
# 124394 1.2 0 768
# 124395 1.2 1 768
# 124396 2.0 1 768
# 124397 2.0 1 768
# 124398 1.2 1 768
# 124399 2.0 1 768
# 124400 1.2 0 768
# 124401 2.0 0 768
# 124402 1.2 0 768
# 124403 1.6 0 768
# 124404 1.2 0 768
# 124405 1.2 1 768
# 124406 1.2 1 768
# 124407 1.2 1 768
# 124408 2.0 1 768
# 124409 1.2 1 768
# 124410 2.0 0 768
# 124411 2.0 1 768
# 124412 1.2 1 768
# 124413 2.0 0 768
# 124414 1.2 1 768
# 124415 2.0 0 768
# 124416 2.0 0 768
# 124417 1.2 1 768
# 124418 1.2 1 768
# 124419 1.6 0 768
# 124420 1.2 1 768
# 124421 1.2 1 768
# 124422 1.2 1 768
# 124423 2.0 0 768
# 124424 2.0 1 768
# 124425 2.0 0 768
# 124426 2.0 1 768
# 124427 2.0 1 768
# 124428 2.0 1 768
# 124429 1.2 1 768
# 124430 1.2 1 768
# 124431 1.2 1 768
# 124432 2.0 0 768
# 124433 2.0 0 768
# 124434 1.2 1 768
# 124435 1.2 0 768
# 124436 1.2 1 768
# 124437 1.2 1 768
# 124438 1.2 1 768
# 124439 2.0 1 768
# 124440 1.4 0 768
# 124441 2.0 1 768
# 124442 1.2 0 768
# 124443 1.2 1 768
# 124444 2.0 1 768
# 124445 2.0 0 768
# 124446 1.6 0 768
# 124447 2.0 1 768
# 124448 1.6 0 768
# 124449 1.2 1 768
# 124450 1.2 1 768
# 124451 1.2 1 768
# 124452 1.2 1 768
# 124453 1.2 0 768
# 124454 1.2 1 768
# 124455 1.2 1 768
# 124456 1.2 0 768
# 124457 1.2 0 768
# 124458 1.2 1 768
# 124459 1.2 1 768
# 124460 2.0 1 768
# 124461 1.2 1 768
# 124462 1.2 1 768
# 124463 1.2 1 768
# 124464 1.2 1 768
# 124465 1.2 1 768
# 124466 1.2 0 768
# 124467 1.2 1 768
# 124468 1.2 0 768
# 124469 2.0 1 768
# 124470 2.0 1 768
# 124471 1.2 0 768
# 124472 1.2 0 768
# 124473 1.2 1 768
# 124474 1.2 0 768
# 124475 2.0 1 768
# 124476 1.2 1 768
# 124477 1.6 0 768
# 124478 1.2 1 768
# 124479 1.6 0 768
# 124480 1.6 0 768
# 124481 1.2 1 768
# 124482 1.2 1 768
# 124483 2.0 0 768
# 124484 1.2 0 768
# 124485 2.0 1 768
# 124486 2.0 1 768
# 124487 2.0 0 768
# 124488 1.6 0 768
# 124489 2.0 0 768
# 124490 1.2 0 768
# 124491 1.6 0 768
# 124492 1.2 0 768
# 124493 1.2 0 768
# 124494 1.6 0 768
# 124495 2.0 1 768
# 124496 1.2 0 768
# 124497 2.0 1 768
# 124498 2.0 0 768
# 124499 1.2 1 768
# 124500 1.2 1 768
# 124501 1.2 1 768
# 124502 1.2 1 768
# 124503 1.6 0 768
# 124504 1.2 1 768
# 124505 1.6 0 768
# 124506 1.2 1 768
# 124507 1.2 1 768
# 124508 1.2 1 768
# 124509 2.0 0 768
# 124510 1.4 0 768
# 124511 2.0 0 768
# 124512 1.2 1 768
# 124513 1.2 1 768
# 124514 1.2 1 768
# 124515 1.2 0 768
# 124516 1.2 1 768
# 124517 1.2 0 768
# 124518 1.2 1 768
# 124519 1.2 0 768
# 124520 2.0 0 768
# 124521 1.2 1 768
# 124522 1.2 0 768
# 124523 1.2 1 768
# 124524 1.2 0 768
# 124525 1.2 1 768
# 124526 2.0 0 768
# 124527 1.2 1 768
# 124528 1.2 0 768
# 124529 1.2 1 768
# 124530 1.2 1 768
# 124531 1.2 0 768
# 124532 2.0 0 768
# 124533 1.6 0 768
# 124534 1.2 0 768
# 124535 1.2 1 768
# 124536 2.0 1 768
# 124537 1.2 0 768
# 124538 1.2 1 768
# 124539 1.2 1 768
# 124540 2.0 0 768
# 124541 2.0 0 768
# 124542 2.0 1 768
# 124543 2.0 1 768
# 124544 1.2 1 768
# 124545 1.2 1 768
# 124546 1.2 1 768
# 124547 2.0 0 768
# 124548 2.0 0 768
# 124549 2.0 0 768
# 124550 2.0 1 768
# 124551 1.2 1 768
# 124552 1.6 1 768
# 124553 2.0 1 768
# 124554 1.2 1 768
# 124555 1.2 1 768
# 124556 2.0 1 768
# 124557 1.2 0 768
# 124558 1.2 1 768
# 124559 1.2 1 768
# 124560 1.2 0 768
# 124561 1.2 0 768
# 124562 1.2 0 768
# 124563 2.0 1 768
# 124564 1.4 1 768
# 124565 1.6 1 768
# 124566 1.2 1 768
# 124567 1.6 0 768
# 124568 1.2 1 768
# 124569 1.2 0 768
# 124570 1.2 1 768
# 124571 2.0 1 768
# 124572 1.2 1 768
# 124573 2.0 1 768
# 124574 1.2 1 768
# 124575 1.2 0 768
# 124576 1.2 1 768
# 124577 2.0 1 768
# 124578 1.2 1 768
# 124579 2.0 1 768
# 124580 1.2 0 768
# 124581 1.2 1 768
# 124582 1.2 1 768
# 124583 1.6 0 768
# 124584 1.2 1 768
# 124585 1.2 1 768
# 124586 1.2 0 768
# 124587 1.2 1 768
# 124588 1.2 0 768
# 124589 1.2 0 768
# 124590 2.0 1 768
# 124591 1.2 0 768
# 124592 1.2 1 768
# 124593 2.0 1 768
# 124594 1.6 0 768
# 124595 1.6 0 768
# 124596 1.2 1 768
# 124597 1.2 1 768
# 124598 1.2 1 768
# 124599 1.2 1 768
# 124600 1.2 1 768
# 124601 1.2 1 768
# 124602 1.2 1 768
# 124603 1.2 1 768
# 124604 2.0 0 768
# 124605 1.2 1 768
# 124606 1.6 0 768
# 124607 2.0 0 768
# 124608 1.2 0 768
# 124609 2.0 0 768
# 124610 2.0 1 768
# 124611 1.2 1 768
# 124612 1.2 1 768
# 124613 2.0 0 768
# 124614 2.0 0 768
# 124615 2.0 0 768
# 124616 1.2 1 768
# 124617 1.2 0 768
# 124618 1.2 1 768
# 124619 1.2 1 768
# 124620 2.0 0 768
# 124621 1.2 1 768
# 124622 1.6 1 768
# 124623 1.2 1 768
# 124624 1.2 0 768
# 124625 2.0 1 768
# 124626 1.2 0 768
# 124627 1.2 0 768
# 124628 1.2 1 768
# 124629 1.6 0 768
# 124630 2.0 1 768
# 124631 2.0 0 768
# 124632 1.2 1 768
# 124633 2.0 0 768
# 124634 1.2 1 768
# 124635 1.2 1 768
# 124636 1.2 1 768
# 124637 1.2 0 768
# 124638 2.0 0 768
# 124639 2.0 1 768
# 124640 1.6 0 768
# 124641 1.2 1 768
# 124642 1.2 0 768
# 124643 2.0 0 768
# 124644 1.2 0 768
# 124645 1.2 1 768
# 124646 1.6 0 768
# 124647 1.2 0 768
# 124648 2.0 1 768
# 124649 1.2 1 768
# 124650 1.2 1 768
# 124651 2.0 1 768
# 124652 1.2 1 768
# 124653 1.6 0 768
# 124654 2.0 0 768
# 124655 1.2 1 768
# 124656 2.0 1 768
# 124657 1.2 1 768
# 124658 1.2 0 768
# 124659 2.0 1 768
# 124660 1.2 1 768
# 124661 1.2 1 768
# 124662 1.2 1 768
# 124663 2.0 0 768
# 124664 2.0 0 768
# 124665 1.2 0 768
# 124666 1.2 1 768
# 124667 1.2 0 768
# 124668 1.2 1 768
# 124669 1.4 0 768
# 124670 1.2 0 768
# 124671 2.0 1 768
# 124672 1.2 0 768
# 124673 2.0 1 768
# 124674 1.6 1 768
# 124675 1.2 1 768
# 124676 1.2 0 768
# 124677 2.0 0 768
# 124678 1.6 0 768
# 124679 1.2 1 768
# 124680 1.2 0 768
# 124681 2.0 0 768
# 124682 1.4 0 768
# 124683 1.2 1 768
# 124684 2.0 1 768
# 124685 1.6 0 768
# 124686 1.2 1 768
# 124687 1.2 0 768
# 124688 2.0 0 768
# 124689 1.2 1 768
# 124690 2.0 0 768
# 124691 1.2 0 768
# 124692 1.2 0 768
# 124693 2.0 0 768
# 124694 1.2 1 768
# 124695 2.0 0 768
# 124696 1.2 1 768
# 124697 1.2 1 768
# 124698 1.2 1 768
# 124699 1.2 1 768
# 124700 1.2 0 768
# 124701 2.0 0 768
# 124702 1.6 0 768
# 124703 1.2 0 768
# 124704 1.2 0 768
# 124705 1.2 1 768
# 124706 1.2 0 768
# 124707 1.6 0 768
# 124708 1.2 1 768
# 124709 1.2 1 768
# 124710 1.2 1 768
# 124711 1.2 1 768
# 124712 1.2 0 768
# 124713 1.2 0 768
# 124714 1.2 0 768
# 124715 2.0 1 768
# 124716 1.6 0 768
# 124717 1.2 0 768
# 124718 1.2 1 768
# 124719 1.2 1 768
# 124720 1.2 0 768
# 124721 1.2 1 768
# 124722 1.2 0 768
# 124723 1.6 0 768
# 124724 1.2 1 768
# 124725 1.6 0 768
# 124726 1.2 1 768
# 124727 1.2 1 768
# 124728 2.0 1 768
# 124729 1.2 0 768
# 124730 2.0 1 768
# 124731 2.0 0 768
# 124732 2.0 0 768
# 124733 1.2 1 768
# 124734 2.0 0 768
# 124735 2.0 0 768
# 124736 1.2 0 768
# 124737 1.2 0 768
# 124738 2.0 0 768
# 124739 1.2 0 768
# 124740 1.2 1 768
# 124741 1.2 1 768
# 124742 2.0 0 768
# 124743 1.2 0 768
# 124744 1.2 1 768
# 124745 1.2 0 768
# 124746 1.2 1 768
# 124747 1.6 0 768
# (torch.Size([124748, 768]), torch.Size([124748]), torch.Size([124748]))

# %%
from sklearn.model_selection import train_test_split

# Splitting the indices for train and validation sets
train_indices, val_indices = train_test_split(range(len(embeddings)), test_size=0.2, random_state=42)
train_indices, val_indices
# Out:
# ([104866,
#   40347,
#   80943,
#   4811,
#   94419,
#   30400,
#   41027,
#   45346,
#   61253,
#   5268,
#   44110,
#   75686,
#   55247,
#   21752,
#   45846,
#   64706,
#   123074,
#   120274,
#   86308,
#   72416,
#   74538,
#   56038,
#   36932,
#   34882,
#   2277,
#   117036,
#   42402,
#   416,
#   113213,
#   42529,
#   33784,
#   73951,
#   12312,
#   21659,
#   37342,
#   34807,
#   29997,
#   13695,
#   115434,
#   53,
#   90428,
#   46248,
#   10852,
#   15815,
#   28759,
#   115344,
#   81648,
#   115750,
#   98491,
#   35570,
#   84869,
#   71940,
#   68949,
#   108325,
#   71346,
#   74708,
#   104430,
#   84812,
#   117243,
#   58417,
#   8565,
#   29609,
#   30738,
#   1790,
#   2307,
#   79730,
#   17148,
#   98069,
#   16331,
#   32466,
#   7129,
#   57892,
#   97834,
#   50005,
#   10671,
#   25637,
#   119160,
#   106392,
#   23608,
#   118631,
#   84404,
#   17815,
#   106645,
#   65893,
#   88042,
#   34183,
#   107125,
#   87482,
#   75365,
#   53259,
#   70625,
#   39719,
#   46781,
#   53809,
#   54968,
#   41158,
#   77494,
#   54477,
#   77238,
#   47916,
#   54809,
#   120896,
#   12347,
#   50053,
#   121202,
#   100580,
#   4084,
#   118219,
#   26785,
#   20174,
#   37954,
#   124354,
#   110316,
#   68770,
#   115946,
#   124395,
#   82875,
#   72202,
#   96613,
#   96932,
#   70937,
#   66164,
#   63453,
#   48502,
#   19687,
#   59492,
#   46670,
#   20940,
#   70741,
#   51247,
#   41802,
#   35801,
#   18626,
#   46238,
#   28320,
#   67732,
#   40921,
#   81821,
#   75627,
#   68409,
#   103713,
#   69679,
#   114438,
#   73642,
#   50718,
#   29313,
#   101944,
#   54804,
#   124498,
#   6989,
#   46789,
#   10268,
#   69910,
#   29306,
#   27646,
#   82218,
#   109892,
#   123207,
#   121342,
#   90208,
#   12959,
#   1668,
#   82347,
#   15621,
#   81351,
#   88773,
#   58422,
#   105339,
#   89346,
#   86446,
#   104943,
#   7441,
#   112122,
#   75005,
#   84824,
#   15469,
#   98248,
#   102275,
#   39972,
#   75825,
#   7870,
#   89799,
#   70095,
#   5002,
#   94471,
#   89095,
#   86186,
#   77871,
#   22373,
#   50591,
#   37466,
#   81682,
#   17302,
#   122314,
#   40974,
#   107094,
#   26621,
#   122625,
#   50505,
#   33482,
#   383,
#   85869,
#   58924,
#   5757,
#   41068,
#   20305,
#   35366,
#   113696,
#   25915,
#   7732,
#   50741,
#   107304,
#   80392,
#   28168,
#   123090,
#   30821,
#   53135,
#   11228,
#   35907,
#   104232,
#   114417,
#   111306,
#   68914,
#   60775,
#   98883,
#   98367,
#   72806,
#   44902,
#   120367,
#   117841,
#   5754,
#   63520,
#   90250,
#   57166,
#   59240,
#   96685,
#   55548,
#   90000,
#   45685,
#   100439,
#   10380,
#   2046,
#   105069,
#   53474,
#   29615,
#   123584,
#   65060,
#   74226,
#   50571,
#   101177,
#   64858,
#   96755,
#   124028,
#   17961,
#   37913,
#   17672,
#   108904,
#   253,
#   45271,
#   26504,
#   2493,
#   117547,
#   40890,
#   74003,
#   37048,
#   110124,
#   107131,
#   58189,
#   81524,
#   106544,
#   41549,
#   100479,
#   56280,
#   37951,
#   100688,
#   11446,
#   61048,
#   104758,
#   88094,
#   15081,
#   494,
#   17494,
#   117571,
#   60997,
#   112010,
#   72004,
#   18822,
#   42409,
#   98444,
#   105053,
#   10668,
#   73577,
#   67167,
#   82198,
#   24083,
#   8857,
#   88724,
#   14737,
#   102860,
#   101383,
#   117265,
#   18981,
#   62596,
#   120063,
#   72857,
#   34834,
#   43557,
#   68496,
#   111313,
#   18439,
#   74853,
#   79662,
#   55953,
#   94038,
#   16407,
#   8388,
#   86536,
#   19448,
#   18207,
#   88492,
#   108518,
#   34060,
#   117744,
#   27958,
#   46387,
#   70957,
#   70099,
#   56412,
#   5519,
#   117971,
#   42596,
#   54955,
#   121093,
#   34686,
#   98286,
#   79635,
#   109106,
#   67142,
#   46288,
#   18575,
#   40590,
#   35131,
#   114784,
#   69756,
#   40102,
#   10742,
#   13027,
#   43783,
#   26236,
#   17249,
#   73672,
#   115326,
#   59253,
#   66053,
#   12033,
#   54092,
#   5158,
#   34123,
#   6192,
#   15610,
#   35926,
#   52061,
#   120836,
#   61890,
#   110884,
#   49006,
#   21423,
#   90501,
#   106321,
#   47394,
#   89428,
#   76393,
#   44160,
#   44831,
#   107386,
#   25770,
#   103167,
#   77234,
#   12282,
#   120600,
#   65589,
#   4670,
#   95934,
#   53571,
#   59002,
#   51820,
#   16710,
#   17030,
#   118886,
#   74622,
#   55688,
#   15598,
#   113697,
#   94136,
#   84447,
#   123529,
#   114587,
#   115695,
#   112825,
#   97929,
#   40091,
#   18024,
#   50957,
#   36477,
#   18023,
#   71079,
#   84535,
#   71858,
#   102623,
#   6969,
#   66154,
#   39549,
#   102938,
#   64573,
#   113823,
#   56311,
#   75883,
#   38853,
#   115092,
#   54163,
#   20612,
#   115896,
#   6422,
#   64171,
#   5558,
#   6153,
#   86241,
#   9517,
#   65575,
#   98672,
#   52111,
#   65977,
#   85612,
#   27300,
#   49461,
#   113337,
#   45325,
#   24590,
#   79375,
#   38213,
#   110493,
#   32451,
#   111155,
#   40534,
#   97498,
#   13033,
#   102975,
#   28408,
#   56024,
#   79744,
#   124513,
#   74494,
#   102345,
#   77412,
#   89133,
#   52465,
#   21986,
#   96807,
#   35758,
#   81649,
#   28486,
#   18072,
#   108009,
#   56621,
#   90459,
#   23258,
#   88494,
#   105589,
#   58593,
#   4707,
#   89917,
#   107073,
#   10303,
#   33137,
#   65823,
#   3861,
#   117644,
#   1877,
#   94239,
#   21956,
#   89793,
#   6616,
#   2107,
#   48574,
#   34538,
#   99550,
#   49287,
#   123273,
#   55837,
#   52155,
#   56975,
#   7333,
#   95474,
#   75035,
#   69124,
#   34147,
#   77048,
#   70837,
#   79007,
#   3284,
#   46773,
#   10098,
#   106099,
#   102767,
#   120188,
#   109073,
#   26718,
#   120691,
#   80248,
#   10660,
#   49498,
#   87761,
#   93620,
#   101781,
#   21456,
#   80412,
#   123340,
#   28121,
#   37552,
#   87921,
#   9002,
#   11790,
#   14514,
#   86910,
#   113729,
#   34305,
#   80305,
#   29724,
#   22667,
#   79393,
#   45994,
#   113992,
#   75015,
#   38029,
#   21578,
#   104873,
#   60499,
#   98702,
#   30547,
#   46370,
#   31410,
#   1603,
#   93811,
#   42799,
#   51286,
#   1037,
#   35621,
#   107036,
#   27800,
#   15287,
#   1512,
#   24872,
#   81841,
#   27680,
#   49114,
#   100684,
#   68599,
#   27381,
#   64728,
#   108256,
#   74584,
#   55667,
#   4657,
#   104270,
#   24114,
#   1888,
#   36578,
#   52353,
#   67247,
#   89724,
#   115737,
#   16096,
#   20730,
#   119432,
#   94155,
#   19247,
#   34292,
#   117159,
#   42833,
#   82845,
#   101209,
#   33391,
#   37022,
#   60741,
#   121466,
#   40892,
#   46013,
#   63487,
#   23841,
#   58063,
#   43482,
#   35250,
#   14366,
#   25450,
#   7827,
#   111725,
#   33229,
#   57611,
#   78453,
#   42386,
#   68779,
#   30433,
#   53892,
#   65892,
#   115349,
#   18853,
#   44882,
#   95323,
#   82396,
#   109202,
#   2546,
#   95091,
#   8999,
#   62156,
#   28072,
#   22009,
#   110324,
#   82154,
#   53786,
#   29294,
#   82130,
#   40040,
#   21152,
#   22328,
#   98942,
#   9263,
#   58167,
#   96966,
#   67328,
#   98874,
#   24132,
#   88999,
#   100011,
#   36083,
#   51429,
#   4658,
#   62329,
#   121524,
#   117008,
#   87831,
#   89463,
#   73234,
#   16278,
#   102124,
#   104819,
#   85942,
#   9403,
#   40145,
#   59385,
#   109143,
#   3738,
#   96518,
#   55768,
#   32231,
#   81707,
#   34776,
#   71682,
#   82065,
#   17992,
#   95458,
#   40119,
#   76901,
#   33805,
#   23338,
#   26488,
#   95215,
#   4452,
#   92006,
#   101714,
#   97407,
#   37316,
#   33491,
#   90968,
#   108420,
#   22056,
#   26733,
#   94762,
#   122899,
#   75655,
#   23591,
#   22276,
#   74127,
#   105988,
#   49218,
#   30853,
#   64130,
#   51859,
#   34639,
#   38837,
#   94255,
#   89733,
#   89867,
#   96527,
#   75387,
#   81566,
#   103702,
#   120424,
#   87094,
#   62673,
#   39389,
#   8113,
#   100216,
#   7343,
#   56303,
#   93494,
#   102846,
#   68370,
#   422,
#   54138,
#   93833,
#   17303,
#   85749,
#   52048,
#   12445,
#   11995,
#   48209,
#   8296,
#   51390,
#   60009,
#   112904,
#   7418,
#   121427,
#   1175,
#   35325,
#   104951,
#   34391,
#   26546,
#   107912,
#   82584,
#   1914,
#   69236,
#   89372,
#   110048,
#   5264,
#   43683,
#   60456,
#   86804,
#   60608,
#   19864,
#   5449,
#   34910,
#   122351,
#   114216,
#   98154,
#   10565,
#   43409,
#   37244,
#   21962,
#   41934,
#   81745,
#   60716,
#   84125,
#   46366,
#   100865,
#   30379,
#   67272,
#   77861,
#   71225,
#   63519,
#   68815,
#   100125,
#   77308,
#   39703,
#   7722,
#   96052,
#   121066,
#   18269,
#   66410,
#   123240,
#   64794,
#   35908,
#   14296,
#   68796,
#   55306,
#   52640,
#   158,
#   20172,
#   2300,
#   34465,
#   96274,
#   55794,
#   55867,
#   120457,
#   96780,
#   31724,
#   86792,
#   42798,
#   33774,
#   80414,
#   61421,
#   76849,
#   37027,
#   3306,
#   23507,
#   96810,
#   22094,
#   86919,
#   113877,
#   20135,
#   66666,
#   32169,
#   40367,
#   12668,
#   33115,
#   87809,
#   100332,
#   61959,
#   84852,
#   103765,
#   41863,
#   84476,
#   45454,
#   82196,
#   29694,
#   92175,
#   1633,
#   98290,
#   50610,
#   97006,
#   22636,
#   11977,
#   56934,
#   108610,
#   110438,
#   92775,
#   47100,
#   100367,
#   562,
#   112884,
#   111764,
#   63349,
#   64521,
#   106023,
#   7475,
#   111416,
#   116724,
#   122273,
#   41701,
#   57160,
#   47765,
#   104370,
#   70748,
#   75816,
#   116585,
#   69197,
#   78338,
#   98862,
#   78574,
#   16736,
#   61139,
#   96295,
#   27589,
#   47134,
#   5957,
#   79060,
#   29065,
#   14305,
#   21614,
#   88067,
#   20265,
#   82024,
#   102371,
#   6942,
#   86304,
#   72614,
#   81799,
#   120361,
#   1736,
#   8035,
#   71864,
#   8854,
#   42456,
#   101524,
#   60134,
#   116623,
#   20415,
#   102718,
#   51228,
#   82935,
#   119616,
#   104114,
#   104557,
#   118577,
#   109783,
#   73930,
#   852,
#   119368,
#   82518,
#   73146,
#   9137,
#   93315,
#   3300,
#   13661,
#   121377,
#   41678,
#   93519,
#   31168,
#   91850,
#   122791,
#   8866,
#   116062,
#   39990,
#   29389,
#   78100,
#   43795,
#   89014,
#   9520,
#   3913,
#   114655,
#   111831,
#   30909,
#   78941,
#   936,
#   58435,
#   90317,
#   10187,
#   101168,
#   79595,
#   8509,
#   80012,
#   95837,
#   108021,
#   80812,
#   14195,
#   61392,
#   83192,
#   68243,
#   70041,
#   19165,
#   102205,
#   27448,
#   84999,
#   121484,
#   64812,
#   90779,
#   88795,
#   12557,
#   48837,
#   92127,
#   83118,
#   111294,
#   47618,
#   86382,
#   73468,
#   88015,
#   16577,
#   15799,
#   4663,
#   37181,
#   23443,
#   97589,
#   64933,
#   81220,
#   69399,
#   3270,
#   118116,
#   27861,
#   54487,
#   93564,
#   71111,
#   77541,
#   15562,
#   1479,
#   74193,
#   117596,
#   52641,
#   13148,
#   78809,
#   106799,
#   90161,
#   25584,
#   16153,
#   30626,
#   22402,
#   97523,
#   24096,
#   3329,
#   61454,
#   108824,
#   78881,
#   60745,
#   22200,
#   46872,
#   101403,
#   65434,
#   1742,
#   14804,
#   54663,
#   81389,
#   53241,
#   2627,
#   99208,
#   26024,
#   25997,
#   30313,
#   32283,
#   25179,
#   100816,
#   28146,
#   2333,
#   ...],
#  [52533,
#   5061,
#   12576,
#   45385,
#   2538,
#   53455,
#   105220,
#   38001,
#   109564,
#   111015,
#   77075,
#   65803,
#   50874,
#   77574,
#   54489,
#   114543,
#   117724,
#   32586,
#   107395,
#   38600,
#   67427,
#   4704,
#   92844,
#   317,
#   51495,
#   110845,
#   44970,
#   49049,
#   14524,
#   101355,
#   91514,
#   92386,
#   62315,
#   107728,
#   15415,
#   83432,
#   54867,
#   19265,
#   95244,
#   39558,
#   18948,
#   39645,
#   86349,
#   31071,
#   57950,
#   121641,
#   56135,
#   5533,
#   110223,
#   81134,
#   74917,
#   69525,
#   18490,
#   49609,
#   72506,
#   90006,
#   35123,
#   93268,
#   88224,
#   120386,
#   31290,
#   48549,
#   119426,
#   97087,
#   23686,
#   105048,
#   92426,
#   108365,
#   99585,
#   56007,
#   90171,
#   104204,
#   1472,
#   27869,
#   63210,
#   50850,
#   108233,
#   114259,
#   60043,
#   120866,
#   107680,
#   100233,
#   77285,
#   21737,
#   7423,
#   82734,
#   36518,
#   87499,
#   44881,
#   113366,
#   110307,
#   36829,
#   86065,
#   8449,
#   49439,
#   77483,
#   86969,
#   118440,
#   98411,
#   46234,
#   2071,
#   115586,
#   14461,
#   114274,
#   3617,
#   8960,
#   30463,
#   113249,
#   28409,
#   91122,
#   91220,
#   46701,
#   14377,
#   10141,
#   92331,
#   55356,
#   15478,
#   12351,
#   84867,
#   66281,
#   56736,
#   31140,
#   75255,
#   112981,
#   66140,
#   112638,
#   6177,
#   27311,
#   108497,
#   16933,
#   24177,
#   70489,
#   2110,
#   33171,
#   21884,
#   54982,
#   28644,
#   95608,
#   30031,
#   54269,
#   18321,
#   64244,
#   88210,
#   75244,
#   6576,
#   57485,
#   65312,
#   46406,
#   32528,
#   80681,
#   111807,
#   118713,
#   104445,
#   30045,
#   89470,
#   53700,
#   47781,
#   9804,
#   3733,
#   33091,
#   111113,
#   25722,
#   17953,
#   35433,
#   81262,
#   50532,
#   47619,
#   104613,
#   19028,
#   79278,
#   48828,
#   856,
#   10202,
#   41320,
#   77464,
#   101333,
#   18270,
#   35150,
#   76042,
#   52876,
#   17190,
#   67366,
#   18875,
#   10791,
#   25141,
#   20334,
#   11987,
#   29915,
#   61364,
#   77594,
#   120890,
#   33963,
#   68188,
#   34892,
#   120143,
#   54201,
#   71272,
#   107684,
#   12250,
#   81875,
#   89261,
#   63377,
#   82776,
#   82177,
#   20306,
#   99917,
#   40766,
#   16986,
#   108262,
#   5286,
#   59731,
#   106872,
#   30994,
#   70536,
#   39010,
#   84421,
#   15780,
#   24991,
#   44461,
#   39108,
#   36252,
#   24013,
#   34153,
#   73461,
#   63707,
#   28275,
#   26241,
#   37809,
#   25108,
#   40501,
#   8062,
#   25145,
#   39626,
#   45864,
#   804,
#   66989,
#   13867,
#   73278,
#   22536,
#   53481,
#   91778,
#   54257,
#   54993,
#   53598,
#   48635,
#   51844,
#   17164,
#   96161,
#   26667,
#   122882,
#   59411,
#   89284,
#   57931,
#   71503,
#   93181,
#   80954,
#   107970,
#   69886,
#   28771,
#   82906,
#   77682,
#   94131,
#   121941,
#   32062,
#   117702,
#   30719,
#   20677,
#   26652,
#   95360,
#   123068,
#   23540,
#   48147,
#   38628,
#   75029,
#   71606,
#   39861,
#   378,
#   88108,
#   15194,
#   93897,
#   84070,
#   107617,
#   12765,
#   40489,
#   119017,
#   96882,
#   84599,
#   100999,
#   886,
#   54747,
#   51650,
#   201,
#   38443,
#   5851,
#   59774,
#   40060,
#   63330,
#   115438,
#   51023,
#   72049,
#   91984,
#   37359,
#   122109,
#   94680,
#   35856,
#   92423,
#   89840,
#   21379,
#   18928,
#   90010,
#   31278,
#   73378,
#   53823,
#   123398,
#   92927,
#   54050,
#   105318,
#   61197,
#   6355,
#   73014,
#   28632,
#   97595,
#   61450,
#   106986,
#   49397,
#   18197,
#   39302,
#   106455,
#   93904,
#   82134,
#   66010,
#   67322,
#   46183,
#   106700,
#   55009,
#   10418,
#   63639,
#   38352,
#   5216,
#   43565,
#   75878,
#   25818,
#   7395,
#   12878,
#   43279,
#   120033,
#   94001,
#   56504,
#   44525,
#   32181,
#   121458,
#   72380,
#   92935,
#   1599,
#   102262,
#   113763,
#   71761,
#   119185,
#   123552,
#   113983,
#   8953,
#   42867,
#   45997,
#   105524,
#   35019,
#   70922,
#   50692,
#   53122,
#   34917,
#   12993,
#   55380,
#   53770,
#   3337,
#   113403,
#   100594,
#   106040,
#   91811,
#   101824,
#   50194,
#   53589,
#   111771,
#   62116,
#   24675,
#   78207,
#   87704,
#   45892,
#   646,
#   980,
#   73955,
#   108584,
#   44833,
#   3064,
#   105370,
#   57092,
#   32017,
#   68611,
#   39482,
#   9456,
#   23844,
#   59759,
#   118885,
#   11466,
#   95413,
#   58848,
#   31808,
#   29596,
#   119997,
#   550,
#   69113,
#   96691,
#   28852,
#   52565,
#   52272,
#   115915,
#   49963,
#   81859,
#   40037,
#   75484,
#   73910,
#   122842,
#   83908,
#   53601,
#   6516,
#   117888,
#   32129,
#   91928,
#   74546,
#   14765,
#   37572,
#   86014,
#   114497,
#   63422,
#   2320,
#   124077,
#   87967,
#   33237,
#   67373,
#   116286,
#   6266,
#   4859,
#   92773,
#   13401,
#   110734,
#   33413,
#   73764,
#   52363,
#   43762,
#   2037,
#   84953,
#   105591,
#   23288,
#   66305,
#   124528,
#   77102,
#   13098,
#   92109,
#   6965,
#   121111,
#   110871,
#   6980,
#   91300,
#   123647,
#   83487,
#   110840,
#   106029,
#   98441,
#   2165,
#   81636,
#   54594,
#   19794,
#   82574,
#   43008,
#   111268,
#   85418,
#   76739,
#   39914,
#   21196,
#   60876,
#   97681,
#   20799,
#   104052,
#   41377,
#   97381,
#   60923,
#   16301,
#   109207,
#   102043,
#   57136,
#   47072,
#   118983,
#   44198,
#   50485,
#   116283,
#   66581,
#   47483,
#   86502,
#   21154,
#   91136,
#   108561,
#   122798,
#   90263,
#   90856,
#   45744,
#   47140,
#   24059,
#   102577,
#   64924,
#   25399,
#   83939,
#   97546,
#   22249,
#   32133,
#   4472,
#   113257,
#   36554,
#   84987,
#   29826,
#   59808,
#   34215,
#   42716,
#   39292,
#   65105,
#   120238,
#   101654,
#   71671,
#   6404,
#   97159,
#   119080,
#   84315,
#   48151,
#   71222,
#   73503,
#   24258,
#   72584,
#   24468,
#   64292,
#   78174,
#   121135,
#   27362,
#   100685,
#   8256,
#   102206,
#   65622,
#   28136,
#   12494,
#   104311,
#   37332,
#   62870,
#   57242,
#   98052,
#   47454,
#   25066,
#   60183,
#   87436,
#   72270,
#   83818,
#   11903,
#   109546,
#   12401,
#   63421,
#   29787,
#   29043,
#   110181,
#   34784,
#   10672,
#   81568,
#   102856,
#   37593,
#   29946,
#   112677,
#   59820,
#   65998,
#   78546,
#   67972,
#   73186,
#   88510,
#   109670,
#   90541,
#   16380,
#   66212,
#   73284,
#   1043,
#   90869,
#   12724,
#   88505,
#   33967,
#   83189,
#   122443,
#   47051,
#   43222,
#   21069,
#   42751,
#   100799,
#   84025,
#   115223,
#   122338,
#   81620,
#   118652,
#   8350,
#   70020,
#   37328,
#   29252,
#   78696,
#   26554,
#   10408,
#   120182,
#   98693,
#   85282,
#   106989,
#   4083,
#   80466,
#   87247,
#   632,
#   47569,
#   116475,
#   64716,
#   58590,
#   89544,
#   74542,
#   25014,
#   7266,
#   80417,
#   9454,
#   99312,
#   107274,
#   3899,
#   51780,
#   72187,
#   47139,
#   43328,
#   62872,
#   107701,
#   42003,
#   118262,
#   113262,
#   80144,
#   108254,
#   118039,
#   27991,
#   111099,
#   38530,
#   47479,
#   109076,
#   25752,
#   96073,
#   85085,
#   13658,
#   75870,
#   52125,
#   29647,
#   115885,
#   68667,
#   105668,
#   76884,
#   5178,
#   41547,
#   27894,
#   47654,
#   37503,
#   94999,
#   54076,
#   111524,
#   61231,
#   79355,
#   108299,
#   38625,
#   35213,
#   95979,
#   105767,
#   43332,
#   69645,
#   80718,
#   36399,
#   102217,
#   6667,
#   41894,
#   103198,
#   50334,
#   61670,
#   99099,
#   26450,
#   12269,
#   14622,
#   14430,
#   118747,
#   36332,
#   63724,
#   50537,
#   90222,
#   30863,
#   63009,
#   15466,
#   36886,
#   28963,
#   88882,
#   112322,
#   50898,
#   26087,
#   64285,
#   81727,
#   58885,
#   31978,
#   108266,
#   120313,
#   2029,
#   14149,
#   39171,
#   119621,
#   16513,
#   77847,
#   94773,
#   29159,
#   10947,
#   58205,
#   87045,
#   24500,
#   101768,
#   15502,
#   79185,
#   17765,
#   97296,
#   26259,
#   29936,
#   33891,
#   67302,
#   76179,
#   17078,
#   21783,
#   6848,
#   97751,
#   114412,
#   49292,
#   49598,
#   18838,
#   85292,
#   100900,
#   65981,
#   100862,
#   114337,
#   5979,
#   68849,
#   37267,
#   112497,
#   4064,
#   86305,
#   99680,
#   105416,
#   8995,
#   970,
#   112241,
#   32560,
#   60779,
#   46869,
#   43546,
#   54198,
#   101171,
#   28422,
#   90906,
#   94657,
#   112088,
#   123362,
#   40867,
#   32957,
#   28492,
#   120785,
#   108731,
#   64968,
#   25767,
#   83862,
#   75654,
#   36266,
#   83783,
#   50655,
#   116404,
#   119705,
#   117731,
#   90780,
#   57780,
#   11461,
#   66698,
#   46161,
#   85098,
#   79246,
#   84903,
#   69857,
#   95369,
#   106417,
#   62567,
#   41133,
#   75540,
#   16293,
#   112791,
#   81359,
#   5649,
#   68875,
#   50159,
#   111363,
#   55957,
#   50981,
#   81157,
#   19141,
#   94367,
#   42312,
#   123415,
#   71286,
#   108571,
#   82590,
#   76836,
#   7843,
#   69355,
#   101374,
#   52950,
#   97528,
#   413,
#   10201,
#   81510,
#   27441,
#   98478,
#   5175,
#   49051,
#   24925,
#   121147,
#   114237,
#   78550,
#   102560,
#   73600,
#   25689,
#   6974,
#   108197,
#   86866,
#   56279,
#   26320,
#   29238,
#   470,
#   81269,
#   113448,
#   124479,
#   10032,
#   120453,
#   106912,
#   54363,
#   109663,
#   104870,
#   70501,
#   62271,
#   81760,
#   28789,
#   70892,
#   9709,
#   44022,
#   67095,
#   4906,
#   14267,
#   103738,
#   101348,
#   92146,
#   110824,
#   90530,
#   17613,
#   86482,
#   79238,
#   33605,
#   48892,
#   104813,
#   94147,
#   21656,
#   75789,
#   30181,
#   108184,
#   69470,
#   33619,
#   1176,
#   79976,
#   52899,
#   575,
#   72874,
#   71766,
#   51385,
#   23962,
#   2040,
#   73405,
#   23322,
#   89337,
#   23934,
#   64062,
#   114124,
#   23882,
#   80387,
#   14625,
#   26915,
#   60804,
#   111172,
#   114331,
#   50090,
#   115597,
#   41959,
#   124453,
#   68705,
#   100501,
#   24983,
#   114790,
#   122021,
#   58091,
#   2540,
#   36319,
#   46780,
#   45780,
#   71618,
#   29414,
#   109498,
#   22613,
#   95294,
#   65204,
#   71146,
#   82064,
#   82621,
#   78215,
#   10341,
#   87139,
#   116066,
#   2734,
#   84712,
#   63260,
#   16212,
#   9573,
#   85505,
#   96273,
#   95231,
#   111412,
#   33966,
#   29141,
#   118102,
#   58416,
#   36467,
#   39951,
#   92213,
#   3955,
#   29454,
#   1938,
#   12078,
#   83921,
#   104691,
#   110297,
#   39112,
#   104805,
#   22526,
#   119070,
#   33045,
#   73426,
#   108736,
#   2280,
#   111465,
#   16801,
#   23418,
#   29423,
#   85531,
#   60050,
#   82697,
#   60202,
#   60465,
#   75289,
#   17983,
#   43895,
#   114756,
#   33680,
#   47902,
#   104322,
#   102025,
#   122140,
#   92546,
#   4878,
#   27983,
#   30551,
#   67006,
#   42901,
#   93760,
#   47816,
#   85646,
#   51215,
#   112076,
#   114493,
#   103545,
#   61458,
#   38847,
#   8600,
#   15838,
#   1841,
#   28135,
#   40820,
#   104145,
#   64116,
#   123764,
#   49398,
#   71021,
#   11177,
#   90572,
#   114824,
#   57243,
#   61270,
#   85512,
#   ...])

# %%
from torch.utils.data import DataLoader

""" split_ratio = 0.8
# Create the dataset and dataloader
train_dataset = CustomDataset(embeddings, labels, reliability_scores)
train_loader = DataLoader(dataset, batch_size=32, shuffle=True) """

train_dataset = CustomDataset(embeddings[train_indices], labels[train_indices], reliability_scores[train_indices])
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

val_dataset = CustomDataset(embeddings[val_indices], labels[val_indices], reliability_scores[val_indices])
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

train_loader, val_loader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x395dea2b0>,
#  <torch.utils.data.dataloader.DataLoader at 0x37d6d37c0>)

# %%
from tqdm import tqdm  # for progress bars

num_epochs = 10

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0.0
    print(f"Epoch [{epoch+1}/{num_epochs}]")

    # Progress bar for the training loop
    for batch_idx, (batch_embeddings, batch_labels, batch_reliability_scores) in enumerate(tqdm(train_loader, desc="Training Batches")):
        # Move data to device
        batch_embeddings = batch_embeddings.to(device)
        batch_labels = batch_labels.to(device)
        batch_reliability_scores = batch_reliability_scores.to(device)

        # Forward pass
        outputs = model(batch_embeddings).squeeze()  # Shape: [batch_size]
        loss = criterion(outputs, batch_labels.float())
        
        # Accumulate the epoch loss for reporting
        epoch_loss += loss.item()
        
        # Backward pass
        loss.backward()
        
        # Custom optimizer step with reliability scores
        custom_optimizer.step(batch_reliability_scores)
        
        # Print batch loss periodically
        print(f"Batch [{batch_idx+1}/{len(train_loader)}], Loss: {loss.item():.4f}")
    
    # Average loss for the epoch
    avg_epoch_loss = epoch_loss / len(train_loader)
    print(f"Training Loss for Epoch [{epoch+1}/{num_epochs}]: {avg_epoch_loss:.4f}")
    
    # Validation phase
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for batch_embeddings, batch_labels, _ in tqdm(val_loader, desc="Validation Batches"):
            # Move validation data to device
            batch_embeddings = batch_embeddings.to(device)
            batch_labels = batch_labels.to(device)

            outputs = model(batch_embeddings).squeeze()
            loss = criterion(outputs, batch_labels.float())
            val_loss += loss.item()
    
    # Average validation loss for the epoch
    avg_val_loss = val_loss / len(val_loader)
    print(f"Validation Loss for Epoch [{epoch+1}/{num_epochs}]: {avg_val_loss:.4f}")
    print("-" * 40)
# Out:
# Epoch [1/10]
# Training Batches:   0%|          | 0/3119 [00:00<?, ?it/s]
